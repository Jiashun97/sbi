# sim224000
# sim225000
# sim226000
# sim227000
# sim228000
# sim229000
# sim230000
# sim231000
# sim232000
# sim233000
# sim234000
# sim235000
# sim236000
# sim237000
# sim238000
# sim239000
# sim240000
# sim241000
# sim242000
# sim243000
# sim244000
# sim245000
# sim246000
# sim247000
# sim248000
# sim249000
# sim250000
# sim251000
# sim252000
# sim253000
# sim254000
# sim255000
# sim256000
# sim257000
# sim258000
# sim259000
# sim260000
# sim261000
# sim262000
# sim263000
# sim264000
# sim265000
# sim266000
# sim267000
# sim268000
# sim269000
# sim270000
# sim271000
# sim272000
# sim273000
# sim274000
# sim275000
# sim276000
# sim277000
# sim278000
# sim279000
# sim280000
# sim281000
# sim282000
# sim283000
# sim284000
# sim285000
# sim286000
# sim287000
# sim288000
# sim289000
# sim290000
# sim291000
# sim292000
# sim293000
# sim294000
# sim295000
# sim296000
# sim297000
# sim298000
# sim299000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(param, x_IDM_train)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 43 epochs.

# %%
mcmc_parameters = dict(num_chains=10,thin=10,warmup_steps=50,init_strategy="proposal")

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
x = simul_LCA_full_simp(np.tile([1,1.5,0.4], (100,1)))
print((100-sum(x[:,1]))/100)
print(x[0:10,:])
# Out:
# sim0
# tensor(0.9800)
# tensor([[1.5250, 0.0000],
#         [1.2400, 0.0000],
#         [2.1500, 0.0000],
#         [0.8360, 0.0000],
#         [3.3680, 0.0000],
#         [0.7630, 0.0000],
#         [1.3050, 0.0000],
#         [0.8190, 0.0000],
#         [2.1850, 0.0000],
#         [1.9070, 0.0000]])

# %%
prior_LCA = utils.BoxUniform(low=[0, 0.6, -0.4, 0.2], high=[1, 1.5, 0, 0.5])

#prior_LCA = utils.BoxUniform(low=[0,0,0.4,0.2], high=[0.4,0.5,0.8,0.5])

LCA_parameters = prior_LCA.sample((20,))

n_trials = 1000
sim_num = 20

par_fitted = np.zeros((sim_num,6))

# %%
for i in range(sim_num):
    print(i)
    LCA_o = simul_LCA_full_simp(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
    print(LCA_parameters[i,:])
    print(LCA_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([ 0.8921,  0.9223, -0.2864,  0.4544])
# tensor([[1.4490, 0.0000],
#         [1.0350, 0.0000],
#         [1.2640, 0.0000],
#         [1.5100, 1.0000],
#         [2.3260, 1.0000],
#         [0.7540, 0.0000],
#         [0.5760, 0.0000],
#         [0.6830, 1.0000],
#         [1.1390, 0.0000],
#         [0.7840, 0.0000]])
# [1.22986265e-01 3.99983466e-01 4.25146341e-01 4.52563092e-02
#  5.15039609e+04 8.59611328e+03]
# 1
# sim0
# tensor([ 0.6318,  0.6754, -0.0060,  0.4920])
# tensor([[1.0060, 0.0000],
#         [0.5710, 0.0000],
#         [0.5110, 0.0000],
#         [0.5150, 1.0000],
#         [1.3460, 0.0000],
#         [0.4940, 0.0000],
#         [1.1290, 0.0000],
#         [0.6500, 0.0000],
#         [1.3170, 0.0000],
#         [0.6670, 0.0000]])
# [8.8749498e-02 5.0555688e-01 4.2071119e-01 5.3854614e-02 5.1543285e+04
#  8.4561475e+03]
# 2
# sim0
# tensor([ 0.6581,  0.8937, -0.0222,  0.3237])
# tensor([[1.7160, 0.0000],
#         [1.0330, 0.0000],
#         [0.4920, 0.0000],
#         [1.7060, 0.0000],
#         [0.5650, 0.0000],
#         [1.2750, 0.0000],
#         [1.6940, 0.0000],
#         [1.2000, 0.0000],
#         [0.9410, 0.0000],
#         [0.7860, 1.0000]])
# [1.6818504e-01 2.8688771e-01 1.5304804e-01 1.0158374e-02 5.2328250e+04
#  8.5959697e+03]
# 3
# sim0
# tensor([ 0.9576,  1.4076, -0.0186,  0.3657])
# tensor([[0.7260, 0.0000],
#         [1.8710, 0.0000],
#         [3.4000, 1.0000],
#         [3.4000, 0.0000],
#         [2.1110, 0.0000],
#         [1.4850, 0.0000],
#         [2.0610, 0.0000],
#         [1.2350, 0.0000],
#         [1.2450, 0.0000],
#         [1.0180, 0.0000]])
# [4.7079065e-01 3.8113111e-01 2.6820382e-01 1.0023747e-02 5.1768961e+04
#  8.2005605e+03]
# 4
# sim0
# tensor([ 0.4855,  1.4635, -0.2737,  0.3051])
# tensor([[0.9310, 0.0000],
#         [0.7740, 0.0000],
#         [1.3020, 0.0000],
#         [0.8960, 0.0000],
#         [3.4000, 0.0000],
#         [2.5700, 0.0000],
#         [3.4000, 1.0000],
#         [1.4650, 0.0000],
#         [2.4620, 0.0000],
#         [2.8360, 0.0000]])
# [6.4451112e-03 4.3515465e-01 1.5037683e-01 4.9054824e-02 5.1501332e+04
#  8.5931582e+03]
# 5
# sim0
# tensor([ 0.9878,  0.9312, -0.1762,  0.3314])
# tensor([[0.8560, 1.0000],
#         [1.0770, 0.0000],
#         [0.5960, 0.0000],
#         [1.0220, 0.0000],
#         [1.4220, 0.0000],
#         [0.8500, 0.0000],
#         [1.9650, 0.0000],
#         [0.6700, 0.0000],
#         [0.9330, 0.0000],
#         [0.6730, 0.0000]])
# [2.3733568e-01 3.0954206e-01 1.6202742e-01 1.0042419e-02 5.2310270e+04
#  8.5679697e+03]
# 6
# sim0
# tensor([ 0.1662,  0.9345, -0.3367,  0.3639])
# tensor([[1.0650, 0.0000],
#         [0.7640, 1.0000],
#         [3.4000, 0.0000],
#         [2.4650, 1.0000],
#         [1.0530, 0.0000],
#         [2.6030, 1.0000],
#         [1.2460, 1.0000],
#         [1.4970, 0.0000],
#         [2.3630, 1.0000],
#         [1.1170, 1.0000]])
# [1.7963609e-02 4.2140770e-01 4.5406073e-01 5.5166513e-02 5.1502719e+04
#  8.5969619e+03]
# 7
# sim0
# tensor([ 0.7339,  1.2867, -0.0640,  0.3586])
# tensor([[0.5880, 0.0000],
#         [1.7130, 0.0000],
#         [2.0770, 0.0000],
#         [1.6160, 0.0000],
#         [0.7300, 1.0000],
#         [1.0900, 0.0000],
#         [2.1990, 1.0000],
#         [1.2890, 0.0000],
#         [0.7410, 0.0000],
#         [0.9650, 0.0000]])
# Optimization was interrupted after 850 iterations.
# [3.3195779e-01 2.7349383e-01 1.4871268e-01 1.0006223e-02 5.1988648e+04
#  8.2022373e+03]
# 8
# sim0
# tensor([ 0.3838,  0.9480, -0.1187,  0.4448])
# tensor([[1.3690, 0.0000],
#         [1.5240, 1.0000],
#         [0.9540, 1.0000],
#         [1.0960, 0.0000],
#         [2.5280, 0.0000],
#         [3.3800, 1.0000],
#         [1.3480, 1.0000],
#         [1.2720, 1.0000],
#         [1.9320, 0.0000],
#         [0.6980, 0.0000]])
# Optimization was interrupted after 13 iterations.
# [9.9191934e-02 4.0027708e-01 4.2980501e-01 3.5840087e-02 5.1561531e+04
#  8.3146885e+03]
# 9
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 3
#       1 for i in range(sim_num):
#       2     print(i)
# ----> 3     LCA_o = simul_LCA_full_simp(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
#       4     print(LCA_parameters[i,:])
#       5     print(LCA_o[0:10,:])
#
# File ~\AppData\Local\Temp\ipykernel_22396\2659340051.py:17, in simul_LCA_full_simp(parameters, dt, c)
#      14 y = 0 # initial location
#      16 while((y<a) and (y>-a)):
# ---> 17     dW = np.random.normal()*np.sqrt(dt)
#      18     dy = (dI - bk*y)*dt + c*dW
#      20     y = y + dy
#
# KeyboardInterrupt:

# %%
# prior_LCA = utils.BoxUniform(low=[0, 0.6, -0.4, 0.2], high=[1, 1.5, 0, 0.5])

par_labels = ["dI","a", "bk","ter"]
par_fitted_labels = ["C", "h", "Ter", "D","W_Exc", "W_Inh", "ter"]
sim_fit_plot_all(LCA_parameters[:7,:], par_fitted[:7,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(12,16))

# %%
# prior_LCA = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])
par_labels = ["dI","a", "bk","ter"]
par_fitted_labels = ["C", "h", "Ter", "D","W_Exc", "W_Inh", "ter"]
sim_fit_plot_all(LCA_parameters[:,:], par_fitted[:,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(12,16))

# %%
LCA_o_correct = LCA_o[LCA_o[:,1]==0]
LCA_o_error = LCA_o[LCA_o[:,1]==1]
print(LCA_parameters[i,:])
print(LCA_o_correct[:,0].shape)

# %%
plt.hist(LCA_o_correct[:,0], bins = 50)
plt.show()

# %%
plt.hist(LCA_o_error[:,0], bins = 50)
plt.show()

# %%
# Out:
# tensor([0.2919, 0.9177, 7.9962, 7.1314, 0.4427, 0.2263])

# %%
# Out:
# torch.Size([511])
