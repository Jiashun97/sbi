# %%
# %run IDM_helper_functions.ipynb

# %%
plt.hist(x[0][:,0], bins = 100)
#plt.show()
# Out:
# (array([17., 45., 64., 58., 41., 48., 42., 44., 28., 26., 30., 33., 29.,
#         23., 21., 18., 16., 17., 19., 14., 12.,  6.,  9., 17., 15.,  9.,
#          6.,  9.,  5., 11.,  7.,  6.,  5.,  1.,  7.,  3.,  2.,  1.,  7.,
#          6.,  4.,  5., 10.,  2.,  3.,  2.,  1.,  4.,  5.,  1.,  1.,  6.,
#          0.,  3.,  1.,  1.,  3.,  1.,  1.,  7.,  5.,  2.,  3.,  2.,  4.,
#          2.,  0.,  3.,  3.,  5.,  3.,  1.,  0.,  4.,  3.,  1.,  0.,  2.,
#          4.,  1.,  4.,  4.,  1.,  1.,  1.,  1.,  1.,  2.,  4.,  2.,  1.,
#          1.,  1.,  1.,  2.,  2.,  1.,  1.,  3., 80.]),
#  array([0.029     , 0.05871   , 0.08842   , 0.11813   , 0.14783999,
#         0.17755   , 0.20726   , 0.23696999, 0.26668   , 0.29639   ,
#         0.32609999, 0.35580999, 0.38552001, 0.41523001, 0.44494   ,
#         0.47465   , 0.50436002, 0.53407001, 0.56378001, 0.59349   ,
#         0.6232    , 0.65290999, 0.68261999, 0.71232998, 0.74203998,
#         0.77174997, 0.80146003, 0.83117002, 0.86088002, 0.89059001,
#         0.92030001, 0.95001   , 0.97972   , 1.00943005, 1.03913999,
#         1.06885004, 1.09855998, 1.12827003, 1.15797997, 1.18769002,
#         1.21739995, 1.24711001, 1.27681994, 1.30653   , 1.33624005,
#         1.36594999, 1.39566004, 1.42536998, 1.45508003, 1.48478997,
#         1.51450002, 1.54420996, 1.57392001, 1.60362995, 1.63334   ,
#         1.66305006, 1.69275999, 1.72247005, 1.75217998, 1.78189003,
#         1.81159997, 1.84131002, 1.87101996, 1.90073001, 1.93043995,
#         1.96015   , 1.98986006, 2.01957011, 2.04927993, 2.07898998,
#         2.10870004, 2.13841009, 2.16811991, 2.19782996, 2.22754002,
#         2.25725007, 2.28695989, 2.31666994, 2.34638   , 2.37609005,
#         2.4058001 , 2.43550992, 2.46521997, 2.49493003, 2.52464008,
#         2.5543499 , 2.58405995, 2.61377001, 2.64348006, 2.67319012,
#         2.70289993, 2.73260999, 2.76232004, 2.7920301 , 2.82173991,
#         2.85144997, 2.88116002, 2.91087008, 2.94057989, 2.97028995,
#         3.        ]),
#  <BarContainer object of 100 artists>)

# %%
x[0][:,0].mean()
# Out:
# tensor(1.0104)

# %%
from collections import Counter

# %% [markdown]
# ## LCA parameter recovery

# %%
# Training data
num_simulations = 100000
#[0,0.5] for ∆I, [0,2] for I, [0,14] for κ and β, [0,1] for Z, and [0,1]
#prior = utils.BoxUniform(low=[0.05,0.05,1,1], high=[0.3,0.25,8,8])

prior = utils.BoxUniform(low=[0.05,0.8,1,1,0.5], high=[0.3,1.2,8,8,0.9])
#prior = utils.BoxU|niform(low=[0.05,0.8,1,1,0.05], high=[0.3,1.2,8,8,0.25])

#prior = utils.BoxUniform(low=[0,0,0,0,0], high=[3,3,14,14,10])

parameters = prior.sample((num_simulations,))
x = simul_LCA5_3AFT(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000

# %%
np.random.normal()
# Out:
# 1.6766225121492337

# %%
x,y1s,y2s,y3s,n_iter = simul_LCA5_3AFT(np.array(([[0.15,1.03,4.62, 2.48, 0.2],
                                            [0.15,1.03,4.62, 2.48, 0.2]])))
# Out:
# sim0

# %%
plt.plot(y1s)
plt.plot(y2s)
plt.plot(y3s)

# %%
n_iter
# Out:
# 62

# %%
# Train MNLE and obtain MCMC-based posterior.
trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
# Out:
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\neural_nets\mnle.py:60: UserWarning: The mixed neural likelihood estimator assumes that x contains
#         continuous data in the first n-1 columns (e.g., reaction times) and
#         categorical data in the last column (e.g., corresponding choices). If
#         this is not the case for the passed `x` do not use this function.
#   warnings.warn(
#  Neural network successfully converged after 56 epochs.

# %%
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")

# %%
# inference with different x_o that has 10 trials
#torch.manual_seed(41)
num_trials = 100
num_samples = 1000
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_LCA5_3AFT(np.array(parameters_o.repeat(num_trials, 1)))
# Out:
# sim0

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)
# Out:
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\utils\sbiutils.py:316: UserWarning: An x with a batch size of 100 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/10100 [00:00<?, ?it/s]
# KeyboardInterrupt

# %%
def pair_plot(prior, mnle_samples, parameters_o, figsize = (5,5),
              contour = 0.7, labels=['I1', 'I2', 'a','Inh','k', 'Ter']):

# %% [markdown]
# ## Simulate from ICA and fit with ICA

# %%
parameters = prior.sample((30,))
n_trials = 1000
par_fitted = np.zeros((30,5))

# %%
for i in range(19,30):
    print(i)
    LCA_o = simul_LCA5_3AFT(np.tile(parameters[i,:], (n_trials,1))) # simulate LCA data
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(parameters[i,:])
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 19
# sim0
# tensor([0.1385, 1.1490, 4.3679, 1.6163, 0.5994])
# [0.10928084 0.9601929  2.5341067  3.0287957  0.5971197 ]
# 20
# sim0
# tensor([0.2981, 1.1609, 4.2112, 3.4342, 0.7373])
# [0.2992433  1.0252002  1.4215986  5.6416698  0.71543014]
# 21
# sim0
# tensor([0.2697, 1.0245, 3.0244, 3.3395, 0.7492])
# [0.29344714 0.9440103  1.7367018  2.982823   0.80995286]
# 22
# sim0
# tensor([0.1830, 1.0212, 2.4080, 4.5705, 0.7632])
# [0.27971515 0.871542   2.1105332  3.1215749  0.8427124 ]
# 23
# sim0
# tensor([0.2639, 0.8247, 5.1912, 2.7421, 0.5216])
# [0.21051633 0.81376696 1.6270206  5.555314   0.5367457 ]
# 24
# sim0
# tensor([0.0885, 1.1605, 3.9938, 1.8342, 0.7698])
# [0.1524558 1.1355441 3.4643202 1.3534987 0.7871473]
# 25
# sim0
# tensor([0.0710, 0.8414, 2.6445, 6.0641, 0.5402])
# [0.07345846 0.8080691  5.7958655  2.5654974  0.5745428 ]
# 26
# sim0
# tensor([0.2039, 1.1345, 2.5953, 7.4432, 0.7832])
# [0.05067345 1.0394962  1.2740182  7.968441   0.817413  ]
# 27
# sim0
# tensor([0.0987, 1.1108, 6.7328, 6.3897, 0.7915])
# [0.05133405 0.8595318  1.1006998  7.8162365  0.86546266]
# 28
# sim0
# tensor([0.2090, 0.8944, 1.0698, 5.6744, 0.6258])
# [0.08665872 0.9171256  1.6424111  4.782776   0.63894653]
# 29
# sim0
# tensor([0.2284, 1.1525, 5.1359, 4.6008, 0.5298])
# [0.26689157 1.0561188  3.582034   6.7773194  0.5139554 ]

# %%
par_labels = ["dI", "I", "inh", "k","a"]
par_fitted_labels = ["dI", "I", "inh", "k","a"]
sim_fit_plot_all(parameters, par_fitted, par_labels, par_fitted_labels,s=15)

# %% [markdown]
# ## Simulate from IDM and fit with ICA

# %%
Cs = np.random.uniform(low=0, high=0.5, size=30)
hs = np.random.uniform(low=0.2, high=0.4, size=30)
Inhs = np.random.uniform(low=8200, high=8600, size=30)
Excs = np.random.uniform(low=52300, high=52700, size=30)

#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 200
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Cs)):
    print(i)
    IDM_o = simul_IDM_CG_inh_pos(np.tile((Cs[i], hs[i], Inhs[i], Excs[i]), (n_trials,1))) # simulate IDM data
    print(IDM_o[0:5,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([[0.6040, 0.0000],
#         [0.6290, 0.0000],
#         [0.6160, 0.0000],
#         [0.5830, 0.0000],
#         [0.6520, 0.0000]])
# [0.49832803 0.8016558  5.9934206 ]
# 1
# sim0
# tensor([[0.6500, 0.0000],
#         [0.6260, 0.0000],
#         [0.6670, 0.0000],
#         [0.6450, 1.0000],
#         [0.6440, 1.0000]])
# [0.49999422 0.9728365  5.9983606 ]
# 2
# sim0
# tensor([[0.6090, 0.0000],
#         [0.5970, 0.0000],
#         [0.6110, 0.0000],
#         [0.6000, 0.0000],
#         [0.5990, 0.0000]])
# [0.49823552 0.70273894 5.994752  ]
# 3
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.6410, 0.0000],
#         [0.6260, 0.0000],
#         [0.6420, 0.0000]])
# [0.4997586 0.8947196 5.9965606]
# 4
# sim0
# tensor([[0.6440, 0.0000],
#         [0.6280, 0.0000],
#         [0.6530, 0.0000],
#         [0.6110, 0.0000],
#         [0.5980, 0.0000]])
# [0.49905163 0.923246   5.9908404 ]
# 5
# sim0
# tensor([[0.5920, 0.0000],
#         [0.5910, 0.0000],
#         [0.5760, 0.0000],
#         [0.5730, 0.0000],
#         [0.5600, 0.0000]])
# [0.49794927 0.6613167  5.980138  ]
# 6
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6250, 0.0000],
#         [0.6430, 0.0000],
#         [0.6110, 1.0000],
#         [0.6220, 1.0000]])
# [0.49955806 0.8662629  5.9875493 ]
# 7
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6120, 1.0000],
#         [0.6030, 1.0000],
#         [0.5640, 1.0000],
#         [0.5710, 0.0000]])
# [0.49610642 0.70116246 5.9933295 ]
# 8
# sim0
# tensor([[0.6350, 0.0000],
#         [0.6060, 0.0000],
#         [0.6240, 1.0000],
#         [0.6640, 0.0000],
#         [0.6260, 0.0000]])
# [0.49981934 0.8839767  5.990653  ]
# 9
# sim0
# tensor([[0.6150, 0.0000],
#         [0.6120, 0.0000],
#         [0.6190, 0.0000],
#         [0.5970, 0.0000],
#         [0.5790, 0.0000]])
# [0.4996581 0.7643739 5.9906983]
# 10
# sim0
# tensor([[0.5710, 0.0000],
#         [0.6260, 0.0000],
#         [0.6170, 1.0000],
#         [0.5790, 0.0000],
#         [0.5860, 0.0000]])
# [0.4931596  0.67706263 5.99936   ]
# 11
# sim0
# tensor([[0.5900, 0.0000],
#         [0.5780, 0.0000],
#         [0.5640, 0.0000],
#         [0.5930, 0.0000],
#         [0.5650, 0.0000]])
# [0.4970345  0.68541336 5.982694  ]
# 12
# sim0
# tensor([[0.6640, 0.0000],
#         [0.6400, 0.0000],
#         [0.6350, 0.0000],
#         [0.6170, 0.0000],
#         [0.6380, 0.0000]])
# [0.4999761  0.99315816 5.977     ]
# 13
# sim0
# tensor([[0.5860, 0.0000],
#         [0.5870, 0.0000],
#         [0.5660, 0.0000],
#         [0.5930, 0.0000],
#         [0.5620, 0.0000]])
# [0.49856782 0.6049225  5.9806437 ]
# 14
# sim0
# tensor([[0.6270, 0.0000],
#         [0.5990, 0.0000],
#         [0.6040, 0.0000],
#         [0.6300, 0.0000],
#         [0.6070, 0.0000]])
# [0.49996006 0.882141   5.992088  ]
# 15
# sim0
# tensor([[0.6230, 0.0000],
#         [0.6130, 0.0000],
#         [0.6460, 0.0000],
#         [0.6430, 0.0000],
#         [0.6450, 1.0000]])
# [0.49990615 0.9029447  5.98905   ]
# 16
# sim0
# tensor([[0.6060, 0.0000],
#         [0.5930, 0.0000],
#         [0.5940, 0.0000],
#         [0.5870, 0.0000],
#         [0.5840, 0.0000]])
# [0.49911994 0.7257694  5.999828  ]
# 17
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6020, 0.0000],
#         [0.6230, 1.0000],
#         [0.6110, 0.0000],
#         [0.6070, 0.0000]])
# [0.49909166 0.8833525  5.9955573 ]
# 18
# sim0
# tensor([[0.6420, 0.0000],
#         [0.6320, 0.0000],
#         [0.6700, 0.0000],
#         [0.6080, 0.0000],
#         [0.6480, 0.0000]])
# [0.49952844 0.99455416 5.993377  ]
# 19
# sim0
# tensor([[0.6290, 0.0000],
#         [0.6410, 0.0000],
#         [0.6630, 0.0000],
#         [0.6460, 0.0000],
#         [0.6260, 0.0000]])
# [0.49965155 0.9481044  5.9942226 ]
# 20
# sim0
# tensor([[0.6510, 0.0000],
#         [0.5810, 0.0000],
#         [0.6090, 0.0000],
#         [0.6280, 0.0000],
#         [0.6250, 0.0000]])
# [0.49969506 0.90398604 5.998883  ]
# 21
# sim0
# tensor([[0.6220, 0.0000],
#         [0.6230, 0.0000],
#         [0.6610, 0.0000],
#         [0.6390, 0.0000],
#         [0.6320, 0.0000]])
# [0.49920246 0.9594071  5.9920926 ]
# 22
# sim0
# tensor([[0.6540, 0.0000],
#         [0.6120, 0.0000],
#         [0.6600, 0.0000],
#         [0.6300, 1.0000],
#         [0.5880, 1.0000]])
# [0.49935114 0.9300163  5.9996824 ]
# 23
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6020, 0.0000],
#         [0.5880, 0.0000],
#         [0.5990, 0.0000],
#         [0.5930, 0.0000]])
# [0.4968602 0.6055591 5.9798117]
# 24
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6270, 0.0000],
#         [0.6140, 0.0000],
#         [0.6440, 0.0000],
#         [0.6290, 0.0000]])
# [0.4999055 0.8643395 5.991871 ]
# 25
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.5820, 0.0000],
#         [0.6090, 0.0000],
#         [0.6040, 1.0000]])
# [0.49931514 0.6956142  5.997257  ]
# 26
# sim0
# tensor([[0.6040, 0.0000],
#         [0.5860, 1.0000],
#         [0.5760, 0.0000],
#         [0.5970, 1.0000],
#         [0.5810, 1.0000]])
# [0.4981468 0.6376165 5.997337 ]
# 27
# sim0
# tensor([[0.6200, 0.0000],
#         [0.6070, 0.0000],
#         [0.6040, 0.0000],
#         [0.5980, 0.0000],
#         [0.5840, 0.0000]])
# [0.4982103  0.74936485 5.992598  ]
# 28
# sim0
# tensor([[0.5910, 0.0000],
#         [0.6220, 0.0000],
#         [0.6220, 0.0000],
#         [0.6040, 0.0000],
#         [0.6040, 0.0000]])
# [0.4999021 0.7649392 5.9953628]
# 29
# sim0
# tensor([[0.6240, 0.0000],
#         [0.5960, 0.0000],
#         [0.6080, 1.0000],
#         [0.6440, 1.0000],
#         [0.5990, 0.0000]])
# [0.49835765 0.75684595 5.999816  ]

# %%
sim_fit_plot_IDM_LCA(Cs, hs, Excs, Inhs, par_fitted, sim_num = 25)

# %% [markdown]
# ## Train NN for IDM

# %%
# Training data
num_simulations = 40000
prior = utils.BoxUniform(low=[0,0.2,6000], high=[0.5,0.6,8000])

parameters = prior.sample((num_simulations,))
x = simul_IDM_CG_inh(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")
# Out:
#  Neural network successfully converged after 70 epochs.

# %% [markdown]
# ## IDM parameter recovery

# %%
# inference with different x_o that has 10 trials
num_trials = 100
num_samples = 100
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_IDM_CG_inh(np.array(parameters_o.repeat(num_trials, 1)))

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)

# %%
#pair_plot(prior, mnle_samples, parameters_o, 
contour = 0.7

fig, ax = pairplot(
    [
        prior.sample((1000,)),
        mnle_samples,
    ],
    points=parameters_o,
    diag="kde",
    upper="contour",
    kde_offdiag=dict(bins=50),
    kde_diag=dict(bins=100),
    contour_offdiag=dict(levels=[contour]),
    points_colors=["k"],
    points_offdiag=dict(marker="*", markersize=10),
    labels=['C', 'h','W_neg'],
    figsize=(5, 5)
)

#plt.sca(ax[1, 1])
plt.legend(
    ["Prior", "MNLE", 'True Parameters'],
    #frameon=False,
    fontsize=8,
    loc = 1
);

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
Is = np.random.uniform(low=0.1, high=4, size=30)
As = np.random.uniform(low=0.4, high=0.8, size=30)
Inhs = np.random.uniform(low=0.1, high=4, size=30)
#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 500
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Is)):
    print(i)
    LCA_o = simul_LCA(np.tile((Is[i], As[i], Inhs[i]), (n_trials,1))) # simulate IDM data
    print(LCA_o[0:5,:])
    #prior = utils.BoxUniform(low=[0,0.2,0.1], high=[0.6,0.6,0.6])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# tensor([[1.4020, 0.0000],
#         [0.8870, 0.0000],
#         [0.5680, 1.0000],
#         [0.6120, 1.0000],
#         [0.7680, 0.0000]])
# [2.0425561e-01 4.0492842e-01 6.8782568e+03]
# 1
# tensor([[0.5740, 0.0000],
#         [0.6490, 0.0000],
#         [0.5950, 0.0000],
#         [0.6080, 0.0000],
#         [0.6730, 0.0000]])
# [3.1178629e-01 4.0015432e-01 6.7044673e+03]
# 2
# tensor([[0.6520, 0.0000],
#         [0.6730, 0.0000],
#         [0.5450, 0.0000],
#         [0.6270, 0.0000],
#         [0.5610, 0.0000]])
# [3.2582918e-01 3.7295932e-01 6.6481040e+03]
# 3
# tensor([[0.7700, 1.0000],
#         [0.5440, 1.0000],
#         [0.8770, 0.0000],
#         [0.6530, 1.0000],
#         [0.8140, 0.0000]])
# [3.1458724e-01 3.6899114e-01 6.6702173e+03]
# 4
# tensor([[0.7770, 0.0000],
#         [0.6260, 0.0000],
#         [0.5700, 0.0000],
#         [0.5200, 0.0000],
#         [0.5620, 0.0000]])
# [3.3504364e-01 4.6827739e-01 6.6119951e+03]
# 5
# tensor([[0.5310, 0.0000],
#         [0.5920, 0.0000],
#         [0.7040, 0.0000],
#         [0.6560, 0.0000],
#         [0.5500, 0.0000]])
# [2.5497144e-01 4.2950249e-01 6.8574941e+03]
# 6
# tensor([[0.9740, 1.0000],
#         [0.7350, 0.0000],
#         [0.5680, 0.0000],
#         [0.5920, 0.0000],
#         [0.7150, 1.0000]])
# [3.3508801e-01 4.1542971e-01 6.6329966e+03]
# 7
# tensor([[0.6470, 1.0000],
#         [0.9840, 1.0000],
#         [0.9550, 1.0000],
#         [0.5900, 0.0000],
#         [0.5990, 0.0000]])
# [2.7737603e-01 3.9426410e-01 6.7631484e+03]
# 8
# tensor([[0.5820, 0.0000],
#         [0.6890, 0.0000],
#         [0.7450, 1.0000],
#         [0.6010, 0.0000],
#         [0.9180, 0.0000]])
# [3.1266564e-01 3.8472694e-01 6.7142646e+03]
# 9
# tensor([[0.5750, 0.0000],
#         [0.5800, 1.0000],
#         [0.6460, 0.0000],
#         [0.6830, 0.0000],
#         [0.6180, 0.0000]])
# [3.5886756e-01 4.5547062e-01 6.5827554e+03]
# 10
# tensor([[0.6920, 0.0000],
#         [0.7720, 1.0000],
#         [0.6220, 0.0000],
#         [0.6210, 0.0000],
#         [0.5980, 0.0000]])
# [3.2778805e-01 3.8484198e-01 6.6716807e+03]
# 11
# tensor([[0.8110, 0.0000],
#         [0.7670, 0.0000],
#         [0.7780, 0.0000],
#         [1.0660, 0.0000],
#         [1.0610, 0.0000]])
# [2.5471941e-01 3.7708202e-01 6.7958218e+03]
# 12
# tensor([[0.5840, 0.0000],
#         [0.5950, 1.0000],
#         [0.5750, 0.0000],
#         [0.8600, 0.0000],
#         [0.5710, 0.0000]])
# [3.2884482e-01 4.2685747e-01 6.6874785e+03]
# 13
# tensor([[0.5740, 0.0000],
#         [0.6150, 0.0000],
#         [0.6100, 0.0000],
#         [0.5570, 0.0000],
#         [0.5600, 0.0000]])
# [3.2902876e-01 4.1371053e-01 6.6836899e+03]
# 14
# tensor([[0.6270, 0.0000],
#         [0.5590, 0.0000],
#         [0.5700, 1.0000],
#         [0.5630, 1.0000],
#         [0.5270, 1.0000]])
# [4.0651277e-02 4.5562041e-01 7.1447197e+03]
# 15
# tensor([[0.5830, 0.0000],
#         [0.6970, 1.0000],
#         [0.6140, 0.0000],
#         [0.6070, 1.0000],
#         [0.5740, 0.0000]])
# [1.5563962e-01 3.9980626e-01 6.9279785e+03]
# 16
# tensor([[0.5880, 1.0000],
#         [0.6120, 0.0000],
#         [0.5380, 1.0000],
#         [0.5710, 0.0000],
#         [0.6430, 0.0000]])
# [3.0507207e-01 3.9272881e-01 6.7101436e+03]
# 17
# tensor([[0.5470, 0.0000],
#         [0.5650, 0.0000],
#         [0.6260, 0.0000],
#         [0.6760, 0.0000],
#         [0.6790, 0.0000]])
# [3.4252295e-01 4.0310645e-01 6.6348833e+03]
# 18
# tensor([[0.6630, 0.0000],
#         [0.6170, 0.0000],
#         [0.7990, 0.0000],
#         [0.8260, 0.0000],
#         [0.5510, 0.0000]])
# [3.9133829e-01 4.3725154e-01 6.5507373e+03]
# 19
# tensor([[0.5490, 0.0000],
#         [0.5240, 0.0000],
#         [0.6500, 0.0000],
#         [0.5420, 0.0000],
#         [0.7150, 1.0000]])
# [3.5094243e-01 4.6943265e-01 6.5506460e+03]
# 20
# tensor([[0.5740, 0.0000],
#         [0.5170, 0.0000],
#         [0.5430, 0.0000],
#         [0.5730, 0.0000],
#         [0.5800, 0.0000]])
# [3.6646584e-01 5.0812370e-01 6.5282617e+03]
# 21
# tensor([[0.6490, 0.0000],
#         [0.5490, 0.0000],
#         [0.5460, 0.0000],
#         [0.7210, 0.0000],
#         [0.7650, 1.0000]])
# [3.2997715e-01 4.2436427e-01 6.6895928e+03]
# 22
# tensor([[0.7250, 0.0000],
#         [0.7790, 0.0000],
#         [0.5780, 1.0000],
#         [0.5200, 0.0000],
#         [0.5500, 0.0000]])
# [3.3828917e-01 3.9363915e-01 6.6569502e+03]
# 23
# tensor([[0.6500, 0.0000],
#         [0.6780, 0.0000],
#         [0.7400, 0.0000],
#         [0.7460, 0.0000],
#         [1.2400, 0.0000]])
# [3.4228805e-01 3.8953337e-01 6.6421338e+03]
# 24
# tensor([[0.5350, 1.0000],
#         [0.5990, 1.0000],
#         [0.6090, 1.0000],
#         [0.6270, 1.0000],
#         [0.5790, 1.0000]])
# [2.5657075e-02 4.6212554e-01 7.1766494e+03]
# 25
# tensor([[0.7900, 0.0000],
#         [0.5390, 0.0000],
#         [0.6230, 1.0000],
#         [0.5560, 0.0000],
#         [0.8210, 1.0000]])
# [2.9782254e-01 3.8493875e-01 6.7385723e+03]
# 26
# tensor([[0.5520, 0.0000],
#         [0.5970, 1.0000],
#         [0.7060, 0.0000],
#         [0.5850, 0.0000],
#         [0.6410, 0.0000]])
# [3.3139294e-01 4.1586161e-01 6.6902632e+03]
# 27
# tensor([[0.5230, 0.0000],
#         [0.5820, 0.0000],
#         [0.5680, 1.0000],
#         [0.5770, 0.0000],
#         [0.6850, 1.0000]])
# [3.8472001e-02 4.6674877e-01 7.1828516e+03]
# 28
# tensor([[0.5940, 0.0000],
#         [0.5820, 0.0000],
#         [0.5860, 0.0000],
#         [0.5610, 0.0000],
#         [0.5340, 0.0000]])
# [3.5524613e-01 4.2447615e-01 6.6381909e+03]
# 29
# tensor([[0.5870, 0.0000],
#         [0.8800, 0.0000],
#         [0.5410, 0.0000],
#         [0.6470, 0.0000],
#         [0.7140, 0.0000]])
# [3.4956574e-01 4.2913672e-01 6.6378193e+03]

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')
