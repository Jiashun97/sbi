# %%
# %run IDM_helper_functions.ipynb

# %%
np.array((x)).shape
# Out:
# (100000, 2)

# %%
x
# Out:
# tensor([[0.8520, 0.0000],
#         [0.4920, 2.0000],
#         [0.4070, 2.0000],
#         ...,
#         [0.1880, 2.0000],
#         [2.0180, 2.0000],
#         [0.2870, 2.0000]])

# %%
plt.hist(np.array((x))[:,0], bins = 100)
#plt.show()
# Out:
# (array([ 827., 3528., 5196., 5467., 5512., 4862., 4478., 4059., 3806.,
#         3307., 3030., 2757., 2453., 2311., 2076., 1990., 1660., 1716.,
#         1535., 1487., 1326., 1294., 1114., 1122., 1008., 1040.,  993.,
#          849.,  852.,  814.,  721.,  718.,  735.,  625.,  647.,  626.,
#          556.,  591.,  555.,  494.,  481.,  443.,  465.,  446.,  395.,
#          391.,  370.,  374.,  349.,  335.,  353.,  327.,  310.,  297.,
#          318.,  287.,  275.,  271.,  261.,  232.,  229.,  223.,  243.,
#          222.,  221.,  217.,  194.,  214.,  187.,  198.,  181.,  190.,
#          154.,  176.,  167.,  168.,  149.,  175.,  156.,  152.,  171.,
#          148.,  149.,  130.,  128.,  128.,  126.,  123.,  115.,  117.,
#           90.,  126.,  113.,  111.,  100.,  112.,  104.,   99.,  115.,
#         8162.]),
#  array([0.018     , 0.04782   , 0.07764   , 0.10746   , 0.13728   ,
#         0.1671    , 0.19691999, 0.22674   , 0.25656   , 0.28637999,
#         0.31619999, 0.34602001, 0.37584001, 0.40566   , 0.43548   ,
#         0.46529999, 0.49511999, 0.52494001, 0.55475998, 0.58458   ,
#         0.61440003, 0.64421999, 0.67404002, 0.70385998, 0.73368001,
#         0.76349998, 0.79332   , 0.82314003, 0.85295999, 0.88278002,
#         0.91259998, 0.94242001, 0.97223997, 1.00206006, 1.03188002,
#         1.06169999, 1.09151995, 1.12134004, 1.15116   , 1.18097997,
#         1.21080005, 1.24062002, 1.27043998, 1.30025995, 1.33008003,
#         1.3599    , 1.38971996, 1.41954005, 1.44936001, 1.47917998,
#         1.50899994, 1.53882003, 1.56863999, 1.59845996, 1.62828004,
#         1.65810001, 1.68791997, 1.71774006, 1.74756002, 1.77737999,
#         1.80719995, 1.83702004, 1.86684   , 1.89665997, 1.92648005,
#         1.95630002, 1.98611999, 2.01593995, 2.04575992, 2.07557988,
#         2.10540009, 2.13522005, 2.16504002, 2.19485998, 2.22467995,
#         2.25449991, 2.28432012, 2.31414008, 2.34396005, 2.37378001,
#         2.40359998, 2.43341994, 2.46323991, 2.49306011, 2.52288008,
#         2.55270004, 2.58252001, 2.61233997, 2.64215994, 2.6719799 ,
#         2.70180011, 2.73162007, 2.76144004, 2.79126   , 2.82107997,
#         2.85089993, 2.8807199 , 2.9105401 , 2.94036007, 2.97018003,
#         3.        ]),
#  <BarContainer object of 100 artists>)

# %%
x[0][:,0].mean()
# Out:
# tensor(1.0104)

# %%
x = x[0]

# %% [markdown]
# ## LCA parameter recovery

# %%
# Training data
num_simulations = 100000
#[0,0.5] for ∆I, [0,2] for I, [0,14] for κ and β, [0,1] for Z, and [0,1]
#prior = utils.BoxUniform(low=[0.05,0.05,1,1], high=[0.3,0.25,8,8])

prior = utils.BoxUniform(low=[0.05,1,1,0.5], high=[0.3,8,8,0.9])
#prior = utils.BoxU|niform(low=[0.05,0.8,1,1,0.05], high=[0.3,1.2,8,8,0.25])

#prior = utils.BoxUniform(low=[0,0,0,0,0], high=[3,3,14,14,10])

parameters = prior.sample((num_simulations,))
x = simul_LCA4_3AFT(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000

# %%
np.random.normal()
# Out:
# 1.6766225121492337

# %%
x,y1s,y2s,y3s,n_iter = simul_LCA5_3AFT(np.array(([[0.15,1.03,4.62, 2.48, 0.2],
                                            [0.15,1.03,4.62, 2.48, 0.2]])))
# Out:
# sim0

# %%
plt.plot(y1s)
plt.plot(y2s)
plt.plot(y3s)

# %%
n_iter
# Out:
# 62

# %%
# Train MNLE and obtain MCMC-based posterior.
trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")
# Out:
#  Neural network successfully converged after 54 epochs.

# %%
# inference with different x_o that has 10 trials
#torch.manual_seed(41)
num_trials = 100
num_samples = 1000
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_LCA5_3AFT(np.array(parameters_o.repeat(num_trials, 1)))
# Out:
# sim0

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)
# Out:
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\utils\sbiutils.py:316: UserWarning: An x with a batch size of 100 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/10100 [00:00<?, ?it/s]
# KeyboardInterrupt

# %%
def pair_plot(prior, mnle_samples, parameters_o, figsize = (5,5),
              contour = 0.7, labels=['I1', 'I2', 'a','Inh','k', 'Ter']):

# %% [markdown]
# ## Simulate from ICA and fit with ICA

# %%
parameters = prior.sample((30,))
n_trials = 1000
par_fitted = np.zeros((30,4))

# %%
for i in range(30):
    print(i)
    LCA_o = simul_LCA4_3AFT(np.tile(parameters[i,:], (n_trials,1))) # simulate LCA data
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(parameters[i,:])
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([0.2737, 6.9362, 2.4500, 0.6180])
# [0.19103946 7.9588823  2.0394278  0.60901105]
# 1
# sim0
# tensor([0.2186, 5.1694, 1.6429, 0.5281])
# [0.13978995 2.1038103  3.8593373  0.53222096]
# 2
# sim0
# tensor([0.1367, 3.6130, 4.3577, 0.6791])
# [0.09454788 2.0545707  5.4273887  0.6727451 ]
# 3
# sim0
# tensor([0.2391, 1.0561, 3.4203, 0.7332])
# [0.09434426 1.0293143  1.6598601  0.7463714 ]
# 4
# sim0
# tensor([0.1953, 5.5606, 5.2335, 0.8502])
# [0.10953886 2.6067317  7.9975133  0.7761476 ]
# 5
# sim0
# tensor([0.0720, 7.6796, 4.1259, 0.8784])
# [0.07241338 2.6770697  7.998545   0.7759751 ]
# 6
# sim0
# tensor([0.2757, 1.6333, 2.8939, 0.6341])
# [0.15128112 2.073682   2.8372333  0.6142651 ]
# 7
# sim0
# tensor([0.2160, 6.5738, 5.0747, 0.8839])
# [0.12523845 2.5885623  7.9986753  0.7982542 ]
# 8
# sim0
# tensor([0.2504, 2.4081, 7.6699, 0.8557])
# [0.29970104 4.2346663  6.6954346  0.8979446 ]
# 9
# sim0
# tensor([0.1927, 1.8466, 6.7237, 0.7153])
# [0.2964272  5.868491   5.747419   0.67456776]
# 10
# sim0
# tensor([0.1949, 7.5357, 1.1737, 0.8980])
# [0.298507  1.4450898 6.5980406 0.7564378]
# 11
# sim0
# tensor([0.1081, 6.8971, 3.5143, 0.6467])
# [0.1600641 2.727163  5.664518  0.6530776]
# 12
# sim0
# tensor([0.1666, 6.9529, 2.4501, 0.7352])
# [0.12022899 1.8010681  6.9299417  0.66845953]
# 13
# sim0
# tensor([0.1029, 5.2121, 6.5199, 0.6885])
# [0.06038616 1.5888014  7.2782073  0.73889613]
# 14
# sim0
# tensor([0.1642, 6.8725, 4.3820, 0.6864])
# [0.17576313 4.9370794  5.5507307  0.67814183]
# 15
# sim0
# tensor([0.1704, 4.4691, 2.4024, 0.6268])
# [0.09184463 1.0033945  4.483485   0.6279336 ]
# 16
# sim0
# tensor([0.2718, 2.7180, 5.0353, 0.5137])
# [0.11197717 6.3630543  1.2494102  0.5149806 ]
# 17
# sim0
# tensor([0.0786, 7.3774, 7.6611, 0.5801])
# [0.05131965 5.676434   5.1819577  0.654572  ]
# 18
# sim0
# tensor([0.2447, 6.2069, 6.9232, 0.7815])
# [0.10028526 2.6606283  7.9992933  0.7839058 ]
# 19
# sim0
# tensor([0.0594, 1.6131, 7.3916, 0.6197])
# [0.06732731 3.7468176  4.330942   0.6533083 ]
# 20
# sim0
# tensor([0.2778, 7.4809, 6.2249, 0.7615])
# [0.07331792 2.5395885  7.997949   0.77032924]
# 21
# sim0
# tensor([0.1124, 1.5069, 5.3179, 0.6594])
# [0.06574024 7.1474967  1.0664858  0.6636283 ]
# 22
# sim0
# tensor([0.1215, 5.3110, 7.9197, 0.8050])
# [0.29979476 4.2386274  6.688143   0.8977338 ]
# 23
# sim0
# Optimization was interrupted after 285 iterations.
# tensor([0.0882, 3.4929, 5.5177, 0.6848])
# [0.09787615 1.2216913  6.725012   0.68867135]
# 24
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 for i in range(30):
#       2     print(i)
# ----> 3     LCA_o = simul_LCA4_3AFT(np.tile(parameters[i,:], (n_trials,1))) # simulate LCA data
#       4     mnle_posterior = trainer.build_posterior(
#       5     mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
#       6     )
#       8     #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
#
# File ~\AppData\Local\Temp\ipykernel_25960\2788337430.py:28, in simul_LCA4_3AFT(parameters, dt, c)
#      25 dy2 = (I2 - k*y2 - inh*y1 - inh*y3)*dt + c*dW2
#      26 dy3 = (I3 - k*y3 - inh*y1 - inh*y2)*dt + c*dW3
# ---> 28 y1 = clamp(y1 + dy1, 0, 100)
#      29 y2 = clamp(y2 + dy2, 0, 100)
#      30 y3 = clamp(y3 + dy3, 0, 100)
#
# File ~\AppData\Local\Temp\ipykernel_25960\2375999865.py:35, in clamp(n, minn, maxn)
#      34 def clamp(n, minn=0.0001, maxn=0.9999):
# ---> 35     return(max(min(maxn, n), minn))
#
# KeyboardInterrupt:

# %%
par_labels = ["dI", "inh", "k","a"]
par_fitted_labels = ["dI", "inh", "k","a"]
sim_fit_plot_all(parameters[0:19,:], par_fitted[0:19,:], par_labels, par_fitted_labels, s=15)

# %% [markdown]
# ## Simulate from IDM and fit with ICA

# %%
Cs = np.random.uniform(low=0, high=0.5, size=30)
hs = np.random.uniform(low=0.2, high=0.4, size=30)
Inhs = np.random.uniform(low=8200, high=8600, size=30)
Excs = np.random.uniform(low=52300, high=52700, size=30)

#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 200
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Cs)):
    print(i)
    IDM_o = simul_IDM_CG_inh_pos(np.tile((Cs[i], hs[i], Inhs[i], Excs[i]), (n_trials,1))) # simulate IDM data
    print(IDM_o[0:5,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([[0.6040, 0.0000],
#         [0.6290, 0.0000],
#         [0.6160, 0.0000],
#         [0.5830, 0.0000],
#         [0.6520, 0.0000]])
# [0.49832803 0.8016558  5.9934206 ]
# 1
# sim0
# tensor([[0.6500, 0.0000],
#         [0.6260, 0.0000],
#         [0.6670, 0.0000],
#         [0.6450, 1.0000],
#         [0.6440, 1.0000]])
# [0.49999422 0.9728365  5.9983606 ]
# 2
# sim0
# tensor([[0.6090, 0.0000],
#         [0.5970, 0.0000],
#         [0.6110, 0.0000],
#         [0.6000, 0.0000],
#         [0.5990, 0.0000]])
# [0.49823552 0.70273894 5.994752  ]
# 3
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.6410, 0.0000],
#         [0.6260, 0.0000],
#         [0.6420, 0.0000]])
# [0.4997586 0.8947196 5.9965606]
# 4
# sim0
# tensor([[0.6440, 0.0000],
#         [0.6280, 0.0000],
#         [0.6530, 0.0000],
#         [0.6110, 0.0000],
#         [0.5980, 0.0000]])
# [0.49905163 0.923246   5.9908404 ]
# 5
# sim0
# tensor([[0.5920, 0.0000],
#         [0.5910, 0.0000],
#         [0.5760, 0.0000],
#         [0.5730, 0.0000],
#         [0.5600, 0.0000]])
# [0.49794927 0.6613167  5.980138  ]
# 6
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6250, 0.0000],
#         [0.6430, 0.0000],
#         [0.6110, 1.0000],
#         [0.6220, 1.0000]])
# [0.49955806 0.8662629  5.9875493 ]
# 7
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6120, 1.0000],
#         [0.6030, 1.0000],
#         [0.5640, 1.0000],
#         [0.5710, 0.0000]])
# [0.49610642 0.70116246 5.9933295 ]
# 8
# sim0
# tensor([[0.6350, 0.0000],
#         [0.6060, 0.0000],
#         [0.6240, 1.0000],
#         [0.6640, 0.0000],
#         [0.6260, 0.0000]])
# [0.49981934 0.8839767  5.990653  ]
# 9
# sim0
# tensor([[0.6150, 0.0000],
#         [0.6120, 0.0000],
#         [0.6190, 0.0000],
#         [0.5970, 0.0000],
#         [0.5790, 0.0000]])
# [0.4996581 0.7643739 5.9906983]
# 10
# sim0
# tensor([[0.5710, 0.0000],
#         [0.6260, 0.0000],
#         [0.6170, 1.0000],
#         [0.5790, 0.0000],
#         [0.5860, 0.0000]])
# [0.4931596  0.67706263 5.99936   ]
# 11
# sim0
# tensor([[0.5900, 0.0000],
#         [0.5780, 0.0000],
#         [0.5640, 0.0000],
#         [0.5930, 0.0000],
#         [0.5650, 0.0000]])
# [0.4970345  0.68541336 5.982694  ]
# 12
# sim0
# tensor([[0.6640, 0.0000],
#         [0.6400, 0.0000],
#         [0.6350, 0.0000],
#         [0.6170, 0.0000],
#         [0.6380, 0.0000]])
# [0.4999761  0.99315816 5.977     ]
# 13
# sim0
# tensor([[0.5860, 0.0000],
#         [0.5870, 0.0000],
#         [0.5660, 0.0000],
#         [0.5930, 0.0000],
#         [0.5620, 0.0000]])
# [0.49856782 0.6049225  5.9806437 ]
# 14
# sim0
# tensor([[0.6270, 0.0000],
#         [0.5990, 0.0000],
#         [0.6040, 0.0000],
#         [0.6300, 0.0000],
#         [0.6070, 0.0000]])
# [0.49996006 0.882141   5.992088  ]
# 15
# sim0
# tensor([[0.6230, 0.0000],
#         [0.6130, 0.0000],
#         [0.6460, 0.0000],
#         [0.6430, 0.0000],
#         [0.6450, 1.0000]])
# [0.49990615 0.9029447  5.98905   ]
# 16
# sim0
# tensor([[0.6060, 0.0000],
#         [0.5930, 0.0000],
#         [0.5940, 0.0000],
#         [0.5870, 0.0000],
#         [0.5840, 0.0000]])
# [0.49911994 0.7257694  5.999828  ]
# 17
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6020, 0.0000],
#         [0.6230, 1.0000],
#         [0.6110, 0.0000],
#         [0.6070, 0.0000]])
# [0.49909166 0.8833525  5.9955573 ]
# 18
# sim0
# tensor([[0.6420, 0.0000],
#         [0.6320, 0.0000],
#         [0.6700, 0.0000],
#         [0.6080, 0.0000],
#         [0.6480, 0.0000]])
# [0.49952844 0.99455416 5.993377  ]
# 19
# sim0
# tensor([[0.6290, 0.0000],
#         [0.6410, 0.0000],
#         [0.6630, 0.0000],
#         [0.6460, 0.0000],
#         [0.6260, 0.0000]])
# [0.49965155 0.9481044  5.9942226 ]
# 20
# sim0
# tensor([[0.6510, 0.0000],
#         [0.5810, 0.0000],
#         [0.6090, 0.0000],
#         [0.6280, 0.0000],
#         [0.6250, 0.0000]])
# [0.49969506 0.90398604 5.998883  ]
# 21
# sim0
# tensor([[0.6220, 0.0000],
#         [0.6230, 0.0000],
#         [0.6610, 0.0000],
#         [0.6390, 0.0000],
#         [0.6320, 0.0000]])
# [0.49920246 0.9594071  5.9920926 ]
# 22
# sim0
# tensor([[0.6540, 0.0000],
#         [0.6120, 0.0000],
#         [0.6600, 0.0000],
#         [0.6300, 1.0000],
#         [0.5880, 1.0000]])
# [0.49935114 0.9300163  5.9996824 ]
# 23
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6020, 0.0000],
#         [0.5880, 0.0000],
#         [0.5990, 0.0000],
#         [0.5930, 0.0000]])
# [0.4968602 0.6055591 5.9798117]
# 24
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6270, 0.0000],
#         [0.6140, 0.0000],
#         [0.6440, 0.0000],
#         [0.6290, 0.0000]])
# [0.4999055 0.8643395 5.991871 ]
# 25
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.5820, 0.0000],
#         [0.6090, 0.0000],
#         [0.6040, 1.0000]])
# [0.49931514 0.6956142  5.997257  ]
# 26
# sim0
# tensor([[0.6040, 0.0000],
#         [0.5860, 1.0000],
#         [0.5760, 0.0000],
#         [0.5970, 1.0000],
#         [0.5810, 1.0000]])
# [0.4981468 0.6376165 5.997337 ]
# 27
# sim0
# tensor([[0.6200, 0.0000],
#         [0.6070, 0.0000],
#         [0.6040, 0.0000],
#         [0.5980, 0.0000],
#         [0.5840, 0.0000]])
# [0.4982103  0.74936485 5.992598  ]
# 28
# sim0
# tensor([[0.5910, 0.0000],
#         [0.6220, 0.0000],
#         [0.6220, 0.0000],
#         [0.6040, 0.0000],
#         [0.6040, 0.0000]])
# [0.4999021 0.7649392 5.9953628]
# 29
# sim0
# tensor([[0.6240, 0.0000],
#         [0.5960, 0.0000],
#         [0.6080, 1.0000],
#         [0.6440, 1.0000],
#         [0.5990, 0.0000]])
# [0.49835765 0.75684595 5.999816  ]

# %%
sim_fit_plot_IDM_LCA(Cs, hs, Excs, Inhs, par_fitted, sim_num = 25)

# %% [markdown]
# ## Train NN for IDM

# %%
# Training data
num_simulations = 40000
prior = utils.BoxUniform(low=[0,0.2,6000], high=[0.5,0.6,8000])

parameters = prior.sample((num_simulations,))
x = simul_IDM_CG_inh(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")
# Out:
#  Neural network successfully converged after 70 epochs.

# %% [markdown]
# ## IDM parameter recovery

# %%
# inference with different x_o that has 10 trials
num_trials = 100
num_samples = 100
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_IDM_CG_inh(np.array(parameters_o.repeat(num_trials, 1)))

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)

# %%
#pair_plot(prior, mnle_samples, parameters_o, 
contour = 0.7

fig, ax = pairplot(
    [
        prior.sample((1000,)),
        mnle_samples,
    ],
    points=parameters_o,
    diag="kde",
    upper="contour",
    kde_offdiag=dict(bins=50),
    kde_diag=dict(bins=100),
    contour_offdiag=dict(levels=[contour]),
    points_colors=["k"],
    points_offdiag=dict(marker="*", markersize=10),
    labels=['C', 'h','W_neg'],
    figsize=(5, 5)
)

#plt.sca(ax[1, 1])
plt.legend(
    ["Prior", "MNLE", 'True Parameters'],
    #frameon=False,
    fontsize=8,
    loc = 1
);

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
Is = np.random.uniform(low=0.1, high=4, size=30)
As = np.random.uniform(low=0.4, high=0.8, size=30)
Inhs = np.random.uniform(low=0.1, high=4, size=30)
#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 500
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Is)):
    print(i)
    LCA_o = simul_LCA(np.tile((Is[i], As[i], Inhs[i]), (n_trials,1))) # simulate IDM data
    print(LCA_o[0:5,:])
    #prior = utils.BoxUniform(low=[0,0.2,0.1], high=[0.6,0.6,0.6])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# tensor([[1.4020, 0.0000],
#         [0.8870, 0.0000],
#         [0.5680, 1.0000],
#         [0.6120, 1.0000],
#         [0.7680, 0.0000]])
# [2.0425561e-01 4.0492842e-01 6.8782568e+03]
# 1
# tensor([[0.5740, 0.0000],
#         [0.6490, 0.0000],
#         [0.5950, 0.0000],
#         [0.6080, 0.0000],
#         [0.6730, 0.0000]])
# [3.1178629e-01 4.0015432e-01 6.7044673e+03]
# 2
# tensor([[0.6520, 0.0000],
#         [0.6730, 0.0000],
#         [0.5450, 0.0000],
#         [0.6270, 0.0000],
#         [0.5610, 0.0000]])
# [3.2582918e-01 3.7295932e-01 6.6481040e+03]
# 3
# tensor([[0.7700, 1.0000],
#         [0.5440, 1.0000],
#         [0.8770, 0.0000],
#         [0.6530, 1.0000],
#         [0.8140, 0.0000]])
# [3.1458724e-01 3.6899114e-01 6.6702173e+03]
# 4
# tensor([[0.7770, 0.0000],
#         [0.6260, 0.0000],
#         [0.5700, 0.0000],
#         [0.5200, 0.0000],
#         [0.5620, 0.0000]])
# [3.3504364e-01 4.6827739e-01 6.6119951e+03]
# 5
# tensor([[0.5310, 0.0000],
#         [0.5920, 0.0000],
#         [0.7040, 0.0000],
#         [0.6560, 0.0000],
#         [0.5500, 0.0000]])
# [2.5497144e-01 4.2950249e-01 6.8574941e+03]
# 6
# tensor([[0.9740, 1.0000],
#         [0.7350, 0.0000],
#         [0.5680, 0.0000],
#         [0.5920, 0.0000],
#         [0.7150, 1.0000]])
# [3.3508801e-01 4.1542971e-01 6.6329966e+03]
# 7
# tensor([[0.6470, 1.0000],
#         [0.9840, 1.0000],
#         [0.9550, 1.0000],
#         [0.5900, 0.0000],
#         [0.5990, 0.0000]])
# [2.7737603e-01 3.9426410e-01 6.7631484e+03]
# 8
# tensor([[0.5820, 0.0000],
#         [0.6890, 0.0000],
#         [0.7450, 1.0000],
#         [0.6010, 0.0000],
#         [0.9180, 0.0000]])
# [3.1266564e-01 3.8472694e-01 6.7142646e+03]
# 9
# tensor([[0.5750, 0.0000],
#         [0.5800, 1.0000],
#         [0.6460, 0.0000],
#         [0.6830, 0.0000],
#         [0.6180, 0.0000]])
# [3.5886756e-01 4.5547062e-01 6.5827554e+03]
# 10
# tensor([[0.6920, 0.0000],
#         [0.7720, 1.0000],
#         [0.6220, 0.0000],
#         [0.6210, 0.0000],
#         [0.5980, 0.0000]])
# [3.2778805e-01 3.8484198e-01 6.6716807e+03]
# 11
# tensor([[0.8110, 0.0000],
#         [0.7670, 0.0000],
#         [0.7780, 0.0000],
#         [1.0660, 0.0000],
#         [1.0610, 0.0000]])
# [2.5471941e-01 3.7708202e-01 6.7958218e+03]
# 12
# tensor([[0.5840, 0.0000],
#         [0.5950, 1.0000],
#         [0.5750, 0.0000],
#         [0.8600, 0.0000],
#         [0.5710, 0.0000]])
# [3.2884482e-01 4.2685747e-01 6.6874785e+03]
# 13
# tensor([[0.5740, 0.0000],
#         [0.6150, 0.0000],
#         [0.6100, 0.0000],
#         [0.5570, 0.0000],
#         [0.5600, 0.0000]])
# [3.2902876e-01 4.1371053e-01 6.6836899e+03]
# 14
# tensor([[0.6270, 0.0000],
#         [0.5590, 0.0000],
#         [0.5700, 1.0000],
#         [0.5630, 1.0000],
#         [0.5270, 1.0000]])
# [4.0651277e-02 4.5562041e-01 7.1447197e+03]
# 15
# tensor([[0.5830, 0.0000],
#         [0.6970, 1.0000],
#         [0.6140, 0.0000],
#         [0.6070, 1.0000],
#         [0.5740, 0.0000]])
# [1.5563962e-01 3.9980626e-01 6.9279785e+03]
# 16
# tensor([[0.5880, 1.0000],
#         [0.6120, 0.0000],
#         [0.5380, 1.0000],
#         [0.5710, 0.0000],
#         [0.6430, 0.0000]])
# [3.0507207e-01 3.9272881e-01 6.7101436e+03]
# 17
# tensor([[0.5470, 0.0000],
#         [0.5650, 0.0000],
#         [0.6260, 0.0000],
#         [0.6760, 0.0000],
#         [0.6790, 0.0000]])
# [3.4252295e-01 4.0310645e-01 6.6348833e+03]
# 18
# tensor([[0.6630, 0.0000],
#         [0.6170, 0.0000],
#         [0.7990, 0.0000],
#         [0.8260, 0.0000],
#         [0.5510, 0.0000]])
# [3.9133829e-01 4.3725154e-01 6.5507373e+03]
# 19
# tensor([[0.5490, 0.0000],
#         [0.5240, 0.0000],
#         [0.6500, 0.0000],
#         [0.5420, 0.0000],
#         [0.7150, 1.0000]])
# [3.5094243e-01 4.6943265e-01 6.5506460e+03]
# 20
# tensor([[0.5740, 0.0000],
#         [0.5170, 0.0000],
#         [0.5430, 0.0000],
#         [0.5730, 0.0000],
#         [0.5800, 0.0000]])
# [3.6646584e-01 5.0812370e-01 6.5282617e+03]
# 21
# tensor([[0.6490, 0.0000],
#         [0.5490, 0.0000],
#         [0.5460, 0.0000],
#         [0.7210, 0.0000],
#         [0.7650, 1.0000]])
# [3.2997715e-01 4.2436427e-01 6.6895928e+03]
# 22
# tensor([[0.7250, 0.0000],
#         [0.7790, 0.0000],
#         [0.5780, 1.0000],
#         [0.5200, 0.0000],
#         [0.5500, 0.0000]])
# [3.3828917e-01 3.9363915e-01 6.6569502e+03]
# 23
# tensor([[0.6500, 0.0000],
#         [0.6780, 0.0000],
#         [0.7400, 0.0000],
#         [0.7460, 0.0000],
#         [1.2400, 0.0000]])
# [3.4228805e-01 3.8953337e-01 6.6421338e+03]
# 24
# tensor([[0.5350, 1.0000],
#         [0.5990, 1.0000],
#         [0.6090, 1.0000],
#         [0.6270, 1.0000],
#         [0.5790, 1.0000]])
# [2.5657075e-02 4.6212554e-01 7.1766494e+03]
# 25
# tensor([[0.7900, 0.0000],
#         [0.5390, 0.0000],
#         [0.6230, 1.0000],
#         [0.5560, 0.0000],
#         [0.8210, 1.0000]])
# [2.9782254e-01 3.8493875e-01 6.7385723e+03]
# 26
# tensor([[0.5520, 0.0000],
#         [0.5970, 1.0000],
#         [0.7060, 0.0000],
#         [0.5850, 0.0000],
#         [0.6410, 0.0000]])
# [3.3139294e-01 4.1586161e-01 6.6902632e+03]
# 27
# tensor([[0.5230, 0.0000],
#         [0.5820, 0.0000],
#         [0.5680, 1.0000],
#         [0.5770, 0.0000],
#         [0.6850, 1.0000]])
# [3.8472001e-02 4.6674877e-01 7.1828516e+03]
# 28
# tensor([[0.5940, 0.0000],
#         [0.5820, 0.0000],
#         [0.5860, 0.0000],
#         [0.5610, 0.0000],
#         [0.5340, 0.0000]])
# [3.5524613e-01 4.2447615e-01 6.6381909e+03]
# 29
# tensor([[0.5870, 0.0000],
#         [0.8800, 0.0000],
#         [0.5410, 0.0000],
#         [0.6470, 0.0000],
#         [0.7140, 0.0000]])
# [3.4956574e-01 4.2913672e-01 6.6378193e+03]

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')
