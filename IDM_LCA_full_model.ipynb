# %%
from pyddm import Model
from pyddm.models import DriftLinear
from pyddm.models import DriftConstant, NoiseConstant, BoundConstant, OverlayNonDecision, ICPointSourceCenter
from pyddm.functions import fit_adjust_model, display_model
import numpy as np

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
# %run IDM_helper_functions.ipynb

import torch
from sbi import utils as utils
from sbi import analysis as analysis
from sbi.inference.base import infer

from sbi.inference import MNLE
from pyro.distributions import InverseGamma
from torch.distributions import Beta, Binomial, Gamma
from sbi.utils import MultipleIndependent

from sbi.inference import MCMCPosterior, VIPosterior, RejectionPosterior
from sbi.utils.torchutils import atleast_2d

from sbi.utils import mcmc_transform
from sbi.inference.potentials.base_potential import BasePotential

# %% [markdown]
# ## LCA parameter recovery

# %%
# Training data
num_simulations = 50000
#[0,0.5] for ∆I, [0,2] for I, [0,14] for κ and β, [0,1] for Z, and [0,1]
#prior = utils.BoxUniform(low=[0.05,0.05,1,1], high=[0.3,0.25,8,8])

prior = utils.BoxUniform(low=[0.8,0.8,0.05,1,1,0.2], high=[1.2,1.2,0.25,8,8,0.5])

parameters = prior.sample((num_simulations,))
x = simul_LCA_full(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 73 epochs.

# %%
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")

# %%
# inference with different x_o that has 10 trials
#torch.manual_seed(41)
num_trials = 250
num_samples = 100
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_LCA_full(np.array(parameters_o.repeat(num_trials, 1)))
# Out:
# sim0

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/1100 [00:00<?, ?it/s]

# %%
#pair_plot(prior, mnle_samples, parameters_o, 
contour = 0.5

fig, ax = pairplot(
    [
        prior.sample((1000,)),
        mnle_samples,
    ],
    points=parameters_o,
    diag="kde",
    upper="contour",
    kde_offdiag=dict(bins=50),
    kde_diag=dict(bins=100),
    #contour_offdiag=dict(levels=[contour]),
    points_colors=["k"],
    points_offdiag=dict(marker="*", markersize=10),
    labels=['I1', 'I2', 'a','Inh','k', 'Ter'],
    figsize=(5, 5)
)

#plt.sca(ax[1, 1])
plt.legend(
    ["Prior", "MNLE", 'True Parameters'],
    #frameon=False,
    fontsize=8,
    loc = 1
);

# %%
parameters = prior.sample((30,))
parameters.shape
# Out:
# torch.Size([30, 4])

# %% [markdown]
# ## Simulate from ICA and fit with ICA

# %%
#Is = np.random.uniform(low=0.05, high=0.3, size=30)
#As = np.random.uniform(low=0.05, high=0.25, size=30)
#Inhs = np.random.uniform(low=1, high=8, size=30)
#ks = np.random.uniform(low=1, high=8, size=30)

parameters = prior.sample((30,))

#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 500
num_samples = 100
par_fitted = np.zeros((30,6))

# %%
for i in range(30):
    print(i)
    LCA_o = simul_LCA_full(np.tile(parameters[i,:], (n_trials,1))) # simulate LCA data
    print(LCA_o[0:5,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([[0.4498, 0.0000],
#         [0.4528, 0.0000],
#         [0.4578, 0.0000],
#         [0.4518, 0.0000],
#         [0.4518, 1.0000]])
# [0.89691365 1.1912788  0.14603305 6.793145   4.526678   0.44577125]
# 1
# sim0
# tensor([[0.3188, 1.0000],
#         [0.3398, 1.0000],
#         [0.3188, 0.0000],
#         [0.3878, 1.0000],
#         [0.3288, 1.0000]])
# [0.8796723  0.8712877  0.17291646 7.351118   4.3784657  0.30759013]
# 2
# sim0
# tensor([[0.3047, 1.0000],
#         [0.3007, 0.0000],
#         [0.4087, 0.0000],
#         [0.3537, 1.0000],
#         [0.2807, 0.0000]])
# [1.0461972  0.9600201  0.1870677  7.2200575  5.320671   0.26938564]
# 3
# sim0
# tensor([[0.4904, 1.0000],
#         [0.4864, 0.0000],
#         [0.4974, 0.0000],
#         [0.4954, 1.0000],
#         [0.4844, 1.0000]])
# [1.1813709  1.0513036  0.10056564 7.0319953  2.358488   0.48171383]
# 4
# sim0
# tensor([[0.3387, 1.0000],
#         [0.2907, 1.0000],
#         [0.2827, 0.0000],
#         [0.2817, 0.0000],
#         [0.2837, 1.0000]])
# [0.8074143  0.9393319  0.11085046 6.9017625  4.71811    0.2788484 ]
# 5
# sim0
# tensor([[0.2821, 0.0000],
#         [0.2361, 1.0000],
#         [0.2351, 1.0000],
#         [0.2611, 0.0000],
#         [0.2341, 1.0000]])
# [1.0966297  1.0540435  0.19149382 5.4648466  1.1071897  0.2160423 ]
# 6
# sim0
# tensor([[0.3343, 0.0000],
#         [0.3283, 1.0000],
#         [0.3423, 0.0000],
#         [0.3753, 0.0000],
#         [0.3363, 0.0000]])
# [0.925372   1.0215157  0.16226067 4.0586805  7.9863715  0.31258318]
# 7
# sim0
# tensor([[0.4976, 0.0000],
#         [0.4916, 1.0000],
#         [0.4986, 1.0000],
#         [0.4936, 1.0000],
#         [0.4906, 1.0000]])
# [0.82754976 1.1604428  0.082791   5.095968   7.742055   0.48868686]
# 8
# sim0
# tensor([[0.2478, 1.0000],
#         [0.2468, 0.0000],
#         [0.3108, 0.0000],
#         [0.2388, 1.0000],
#         [0.3698, 1.0000]])
# [0.870764   0.85096264 0.1555437  6.218155   4.4451447  0.22452725]
# 9
# sim0
# tensor([[0.4237, 1.0000],
#         [0.4207, 0.0000],
#         [0.4277, 0.0000],
#         [0.4377, 0.0000],
#         [0.4227, 0.0000]])
# [1.1978108  0.8670211  0.08833311 5.8044977  3.9625735  0.4175141 ]
# 10
# sim0
# tensor([[0.4713, 1.0000],
#         [0.4723, 0.0000],
#         [0.4873, 1.0000],
#         [0.4703, 1.0000],
#         [0.4753, 0.0000]])
# [1.068941   0.8827711  0.11866044 2.8046906  7.4318867  0.46548766]
# 11
# sim0
# tensor([[0.5138, 1.0000],
#         [0.4928, 1.0000],
#         [0.5048, 0.0000],
#         [0.5068, 1.0000],
#         [0.5018, 0.0000]])
# [1.0895839  1.0143404  0.12656099 6.203688   1.7258021  0.47925532]
# 12
# sim0
# tensor([[0.3194, 0.0000],
#         [0.3554, 0.0000],
#         [0.3044, 1.0000],
#         [0.3074, 1.0000],
#         [0.3254, 0.0000]])
# [0.8463546  0.9516911  0.19784802 6.100587   2.9901452  0.29336688]
# 13
# sim0
# tensor([[0.3013, 0.0000],
#         [0.3183, 0.0000],
#         [0.3553, 1.0000],
#         [0.3483, 0.0000],
#         [0.4473, 1.0000]])
# [0.83241314 0.9004823  0.23950271 4.971218   5.514886   0.28856662]
# 14
# sim0
# tensor([[0.4286, 0.0000],
#         [0.4186, 0.0000],
#         [0.4196, 1.0000],
#         [0.4166, 1.0000],
#         [0.4196, 1.0000]])
# [1.0508258  0.8978207  0.05537044 3.6873384  1.2863419  0.41314712]
# 15
# sim0
# tensor([[0.2437, 0.0000],
#         [0.2407, 0.0000],
#         [0.2437, 1.0000],
#         [0.2357, 0.0000],
#         [0.2597, 0.0000]])
# [0.95551866 0.80734116 0.11799891 2.8676164  1.6123623  0.23212604]
# 16
# sim0
# tensor([[0.4545, 1.0000],
#         [0.4575, 1.0000],
#         [0.4515, 0.0000],
#         [0.4565, 1.0000],
#         [0.4485, 1.0000]])
# [1.1333274  0.81599915 0.09269299 1.2671849  2.7996554  0.4451297 ]
# 17
# sim0
# tensor([[0.4466, 1.0000],
#         [0.4646, 1.0000],
#         [0.4506, 1.0000],
#         [0.4826, 0.0000],
#         [0.4496, 0.0000]])
# [1.0225148  0.9838163  0.16818489 7.830707   1.401644   0.43522003]
# 18
# sim0
# tensor([[0.2914, 0.0000],
#         [0.2824, 0.0000],
#         [0.2834, 0.0000],
#         [0.2904, 0.0000],
#         [0.2904, 1.0000]])
# [1.0596145  0.8548065  0.1001679  1.3077568  6.857869   0.27674755]
# 19
# sim0
# tensor([[0.3930, 1.0000],
#         [0.3970, 0.0000],
#         [0.3940, 1.0000],
#         [0.3890, 1.0000],
#         [0.4340, 0.0000]])
# [1.1753805 0.9972131 0.0705364 7.9050198 1.5644209 0.385145 ]
# 20
# sim0
# tensor([[0.2431, 0.0000],
#         [0.2241, 0.0000],
#         [0.2231, 0.0000],
#         [0.2261, 0.0000],
#         [0.2241, 1.0000]])
# [1.1790793  0.924203   0.11558618 6.8702087  1.0968788  0.22101158]
# 21
# sim0
# tensor([[0.4994, 0.0000],
#         [0.5244, 1.0000],
#         [0.6694, 1.0000],
#         [0.4894, 0.0000],
#         [0.4924, 1.0000]])
# [1.0341369  1.1134849  0.19035427 7.3585606  7.310624   0.48002523]
# 22
# sim0
# tensor([[0.4713, 1.0000],
#         [0.4793, 1.0000],
#         [0.4693, 1.0000],
#         [0.4713, 0.0000],
#         [0.4693, 1.0000]])
# [1.0285434  0.8043145  0.05009587 2.402508   1.1822083  0.46629727]
# 23
# sim0
# tensor([[0.5026, 0.0000],
#         [0.4956, 0.0000],
#         [0.5036, 0.0000],
#         [0.4976, 1.0000],
#         [0.4946, 1.0000]])
# [1.1942997  0.8179158  0.05782958 4.1880054  1.1009371  0.4907524 ]
# 24
# sim0
# tensor([[0.4771, 1.0000],
#         [0.5131, 0.0000],
#         [0.4751, 0.0000],
#         [0.4801, 0.0000],
#         [0.4691, 1.0000]])
# [1.0533199  0.9196998  0.12419157 7.020179   1.0514913  0.46366757]
# 25
# sim0
# tensor([[0.3345, 1.0000],
#         [0.3295, 0.0000],
#         [0.3395, 0.0000],
#         [0.3935, 0.0000],
#         [0.3425, 0.0000]])
# [1.1033665  1.0959054  0.14489509 4.8838134  5.528359   0.32140794]
# 26
# sim0
# tensor([[0.4552, 0.0000],
#         [0.4712, 0.0000],
#         [0.4532, 0.0000],
#         [0.4572, 1.0000],
#         [0.4522, 0.0000]])
# Optimization was interrupted after 647 iterations.
# [0.9827036  0.9379293  0.17267999 6.049805   1.1014867  0.4464188 ]
# 27
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_20816/101883786.py in <module>
#       1 for i in range(30):
#       2     print(i)
# ----> 3     LCA_o = simul_LCA_full(np.tile(parameters[i,:], (n_trials,1))) # simulate LCA data
#       4     print(LCA_o[0:5,:])
#       5     mnle_posterior = trainer.build_posterior(
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_20816/3713892570.py in simul_LCA_full(parameters, dt, c)
#      14         y1,y2 = 0,0 # initial location
#      15
# ---> 16         while(get_state_LCA_full(y1,y2,a)==2):
#      17             dW1, dW2 = np.random.normal()*np.sqrt(dt), np.random.normal()*np.sqrt(dt)
#      18
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_20816/2612906437.py in get_state_LCA_full(y1, y2, a)
# ----> 1 def get_state_LCA_full(y1,y2,a):  ## can we also add the second threshold for Andrew's model?
#       2     #print(y1,y2,a)
#       3     if (y1 > a) and (y2 < a):
#       4         state = 0  # 0 for option 1
#       5     elif (y2 > a) and (y1 < a):
#
# KeyboardInterrupt:

# %%
par_labels = ["I1", "I2","a", "inh", "k","Ter"]
par_fitted_labels = ["I1", "I2","a", "inh", "k","Ter"]
sim_fit_plot_all(parameters, par_fitted, par_labels, par_fitted_labels, sim_num = 26)

# %%
sim_fit_plot_4(parameters[0:15,0], parameters[0:15,1], parameters[0:15,2], parameters[0:15,3], par_fitted[0:15,:])

# %% [markdown]
# ## Simulate from IDM and fit with ICA

# %%
Cs = np.random.uniform(low=0, high=0.5, size=30)
hs = np.random.uniform(low=0.2, high=0.4, size=30)
Inhs = np.random.uniform(low=8200, high=8600, size=30)
Excs = np.random.uniform(low=52300, high=52700, size=30)

#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 200
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Cs)):
    print(i)
    IDM_o = simul_IDM_CG_inh_pos(np.tile((Cs[i], hs[i], Inhs[i], Excs[i]), (n_trials,1))) # simulate IDM data
    print(IDM_o[0:5,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([[0.6040, 0.0000],
#         [0.6290, 0.0000],
#         [0.6160, 0.0000],
#         [0.5830, 0.0000],
#         [0.6520, 0.0000]])
# [0.49832803 0.8016558  5.9934206 ]
# 1
# sim0
# tensor([[0.6500, 0.0000],
#         [0.6260, 0.0000],
#         [0.6670, 0.0000],
#         [0.6450, 1.0000],
#         [0.6440, 1.0000]])
# [0.49999422 0.9728365  5.9983606 ]
# 2
# sim0
# tensor([[0.6090, 0.0000],
#         [0.5970, 0.0000],
#         [0.6110, 0.0000],
#         [0.6000, 0.0000],
#         [0.5990, 0.0000]])
# [0.49823552 0.70273894 5.994752  ]
# 3
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.6410, 0.0000],
#         [0.6260, 0.0000],
#         [0.6420, 0.0000]])
# [0.4997586 0.8947196 5.9965606]
# 4
# sim0
# tensor([[0.6440, 0.0000],
#         [0.6280, 0.0000],
#         [0.6530, 0.0000],
#         [0.6110, 0.0000],
#         [0.5980, 0.0000]])
# [0.49905163 0.923246   5.9908404 ]
# 5
# sim0
# tensor([[0.5920, 0.0000],
#         [0.5910, 0.0000],
#         [0.5760, 0.0000],
#         [0.5730, 0.0000],
#         [0.5600, 0.0000]])
# [0.49794927 0.6613167  5.980138  ]
# 6
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6250, 0.0000],
#         [0.6430, 0.0000],
#         [0.6110, 1.0000],
#         [0.6220, 1.0000]])
# [0.49955806 0.8662629  5.9875493 ]
# 7
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6120, 1.0000],
#         [0.6030, 1.0000],
#         [0.5640, 1.0000],
#         [0.5710, 0.0000]])
# [0.49610642 0.70116246 5.9933295 ]
# 8
# sim0
# tensor([[0.6350, 0.0000],
#         [0.6060, 0.0000],
#         [0.6240, 1.0000],
#         [0.6640, 0.0000],
#         [0.6260, 0.0000]])
# [0.49981934 0.8839767  5.990653  ]
# 9
# sim0
# tensor([[0.6150, 0.0000],
#         [0.6120, 0.0000],
#         [0.6190, 0.0000],
#         [0.5970, 0.0000],
#         [0.5790, 0.0000]])
# [0.4996581 0.7643739 5.9906983]
# 10
# sim0
# tensor([[0.5710, 0.0000],
#         [0.6260, 0.0000],
#         [0.6170, 1.0000],
#         [0.5790, 0.0000],
#         [0.5860, 0.0000]])
# [0.4931596  0.67706263 5.99936   ]
# 11
# sim0
# tensor([[0.5900, 0.0000],
#         [0.5780, 0.0000],
#         [0.5640, 0.0000],
#         [0.5930, 0.0000],
#         [0.5650, 0.0000]])
# [0.4970345  0.68541336 5.982694  ]
# 12
# sim0
# tensor([[0.6640, 0.0000],
#         [0.6400, 0.0000],
#         [0.6350, 0.0000],
#         [0.6170, 0.0000],
#         [0.6380, 0.0000]])
# [0.4999761  0.99315816 5.977     ]
# 13
# sim0
# tensor([[0.5860, 0.0000],
#         [0.5870, 0.0000],
#         [0.5660, 0.0000],
#         [0.5930, 0.0000],
#         [0.5620, 0.0000]])
# [0.49856782 0.6049225  5.9806437 ]
# 14
# sim0
# tensor([[0.6270, 0.0000],
#         [0.5990, 0.0000],
#         [0.6040, 0.0000],
#         [0.6300, 0.0000],
#         [0.6070, 0.0000]])
# [0.49996006 0.882141   5.992088  ]
# 15
# sim0
# tensor([[0.6230, 0.0000],
#         [0.6130, 0.0000],
#         [0.6460, 0.0000],
#         [0.6430, 0.0000],
#         [0.6450, 1.0000]])
# [0.49990615 0.9029447  5.98905   ]
# 16
# sim0
# tensor([[0.6060, 0.0000],
#         [0.5930, 0.0000],
#         [0.5940, 0.0000],
#         [0.5870, 0.0000],
#         [0.5840, 0.0000]])
# [0.49911994 0.7257694  5.999828  ]
# 17
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6020, 0.0000],
#         [0.6230, 1.0000],
#         [0.6110, 0.0000],
#         [0.6070, 0.0000]])
# [0.49909166 0.8833525  5.9955573 ]
# 18
# sim0
# tensor([[0.6420, 0.0000],
#         [0.6320, 0.0000],
#         [0.6700, 0.0000],
#         [0.6080, 0.0000],
#         [0.6480, 0.0000]])
# [0.49952844 0.99455416 5.993377  ]
# 19
# sim0
# tensor([[0.6290, 0.0000],
#         [0.6410, 0.0000],
#         [0.6630, 0.0000],
#         [0.6460, 0.0000],
#         [0.6260, 0.0000]])
# [0.49965155 0.9481044  5.9942226 ]
# 20
# sim0
# tensor([[0.6510, 0.0000],
#         [0.5810, 0.0000],
#         [0.6090, 0.0000],
#         [0.6280, 0.0000],
#         [0.6250, 0.0000]])
# [0.49969506 0.90398604 5.998883  ]
# 21
# sim0
# tensor([[0.6220, 0.0000],
#         [0.6230, 0.0000],
#         [0.6610, 0.0000],
#         [0.6390, 0.0000],
#         [0.6320, 0.0000]])
# [0.49920246 0.9594071  5.9920926 ]
# 22
# sim0
# tensor([[0.6540, 0.0000],
#         [0.6120, 0.0000],
#         [0.6600, 0.0000],
#         [0.6300, 1.0000],
#         [0.5880, 1.0000]])
# [0.49935114 0.9300163  5.9996824 ]
# 23
# sim0
# tensor([[0.5780, 0.0000],
#         [0.6020, 0.0000],
#         [0.5880, 0.0000],
#         [0.5990, 0.0000],
#         [0.5930, 0.0000]])
# [0.4968602 0.6055591 5.9798117]
# 24
# sim0
# tensor([[0.6240, 0.0000],
#         [0.6270, 0.0000],
#         [0.6140, 0.0000],
#         [0.6440, 0.0000],
#         [0.6290, 0.0000]])
# [0.4999055 0.8643395 5.991871 ]
# 25
# sim0
# tensor([[0.5920, 0.0000],
#         [0.6100, 0.0000],
#         [0.5820, 0.0000],
#         [0.6090, 0.0000],
#         [0.6040, 1.0000]])
# [0.49931514 0.6956142  5.997257  ]
# 26
# sim0
# tensor([[0.6040, 0.0000],
#         [0.5860, 1.0000],
#         [0.5760, 0.0000],
#         [0.5970, 1.0000],
#         [0.5810, 1.0000]])
# [0.4981468 0.6376165 5.997337 ]
# 27
# sim0
# tensor([[0.6200, 0.0000],
#         [0.6070, 0.0000],
#         [0.6040, 0.0000],
#         [0.5980, 0.0000],
#         [0.5840, 0.0000]])
# [0.4982103  0.74936485 5.992598  ]
# 28
# sim0
# tensor([[0.5910, 0.0000],
#         [0.6220, 0.0000],
#         [0.6220, 0.0000],
#         [0.6040, 0.0000],
#         [0.6040, 0.0000]])
# [0.4999021 0.7649392 5.9953628]
# 29
# sim0
# tensor([[0.6240, 0.0000],
#         [0.5960, 0.0000],
#         [0.6080, 1.0000],
#         [0.6440, 1.0000],
#         [0.5990, 0.0000]])
# [0.49835765 0.75684595 5.999816  ]

# %%
sim_fit_plot_IDM_LCA(Cs, hs, Excs, Inhs, par_fitted, sim_num = 25)

# %% [markdown]
# ## Train NN for IDM

# %%
# Training data
num_simulations = 40000
prior = utils.BoxUniform(low=[0,0.2,6000], high=[0.5,0.6,8000])

parameters = prior.sample((num_simulations,))
x = simul_IDM_CG_inh(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")
# Out:
#  Neural network successfully converged after 70 epochs.

# %% [markdown]
# ## IDM parameter recovery

# %%
# inference with different x_o that has 10 trials
num_trials = 100
num_samples = 100
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_IDM_CG_inh(np.array(parameters_o.repeat(num_trials, 1)))

# %%
mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)

# %%
#pair_plot(prior, mnle_samples, parameters_o, 
contour = 0.7

fig, ax = pairplot(
    [
        prior.sample((1000,)),
        mnle_samples,
    ],
    points=parameters_o,
    diag="kde",
    upper="contour",
    kde_offdiag=dict(bins=50),
    kde_diag=dict(bins=100),
    contour_offdiag=dict(levels=[contour]),
    points_colors=["k"],
    points_offdiag=dict(marker="*", markersize=10),
    labels=['C', 'h','W_neg'],
    figsize=(5, 5)
)

#plt.sca(ax[1, 1])
plt.legend(
    ["Prior", "MNLE", 'True Parameters'],
    #frameon=False,
    fontsize=8,
    loc = 1
);

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
Is = np.random.uniform(low=0.1, high=4, size=30)
As = np.random.uniform(low=0.4, high=0.8, size=30)
Inhs = np.random.uniform(low=0.1, high=4, size=30)
#Ters = np.random.uniform(low=0.2, high=0.8, size=30)

n_trials = 500
num_samples = 100
par_fitted = np.zeros((30,3))

# %%
for i in range(len(Is)):
    print(i)
    LCA_o = simul_LCA(np.tile((Is[i], As[i], Inhs[i]), (n_trials,1))) # simulate IDM data
    print(LCA_o[0:5,:])
    #prior = utils.BoxUniform(low=[0,0.2,0.1], high=[0.6,0.6,0.6])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# tensor([[1.4020, 0.0000],
#         [0.8870, 0.0000],
#         [0.5680, 1.0000],
#         [0.6120, 1.0000],
#         [0.7680, 0.0000]])
# [2.0425561e-01 4.0492842e-01 6.8782568e+03]
# 1
# tensor([[0.5740, 0.0000],
#         [0.6490, 0.0000],
#         [0.5950, 0.0000],
#         [0.6080, 0.0000],
#         [0.6730, 0.0000]])
# [3.1178629e-01 4.0015432e-01 6.7044673e+03]
# 2
# tensor([[0.6520, 0.0000],
#         [0.6730, 0.0000],
#         [0.5450, 0.0000],
#         [0.6270, 0.0000],
#         [0.5610, 0.0000]])
# [3.2582918e-01 3.7295932e-01 6.6481040e+03]
# 3
# tensor([[0.7700, 1.0000],
#         [0.5440, 1.0000],
#         [0.8770, 0.0000],
#         [0.6530, 1.0000],
#         [0.8140, 0.0000]])
# [3.1458724e-01 3.6899114e-01 6.6702173e+03]
# 4
# tensor([[0.7770, 0.0000],
#         [0.6260, 0.0000],
#         [0.5700, 0.0000],
#         [0.5200, 0.0000],
#         [0.5620, 0.0000]])
# [3.3504364e-01 4.6827739e-01 6.6119951e+03]
# 5
# tensor([[0.5310, 0.0000],
#         [0.5920, 0.0000],
#         [0.7040, 0.0000],
#         [0.6560, 0.0000],
#         [0.5500, 0.0000]])
# [2.5497144e-01 4.2950249e-01 6.8574941e+03]
# 6
# tensor([[0.9740, 1.0000],
#         [0.7350, 0.0000],
#         [0.5680, 0.0000],
#         [0.5920, 0.0000],
#         [0.7150, 1.0000]])
# [3.3508801e-01 4.1542971e-01 6.6329966e+03]
# 7
# tensor([[0.6470, 1.0000],
#         [0.9840, 1.0000],
#         [0.9550, 1.0000],
#         [0.5900, 0.0000],
#         [0.5990, 0.0000]])
# [2.7737603e-01 3.9426410e-01 6.7631484e+03]
# 8
# tensor([[0.5820, 0.0000],
#         [0.6890, 0.0000],
#         [0.7450, 1.0000],
#         [0.6010, 0.0000],
#         [0.9180, 0.0000]])
# [3.1266564e-01 3.8472694e-01 6.7142646e+03]
# 9
# tensor([[0.5750, 0.0000],
#         [0.5800, 1.0000],
#         [0.6460, 0.0000],
#         [0.6830, 0.0000],
#         [0.6180, 0.0000]])
# [3.5886756e-01 4.5547062e-01 6.5827554e+03]
# 10
# tensor([[0.6920, 0.0000],
#         [0.7720, 1.0000],
#         [0.6220, 0.0000],
#         [0.6210, 0.0000],
#         [0.5980, 0.0000]])
# [3.2778805e-01 3.8484198e-01 6.6716807e+03]
# 11
# tensor([[0.8110, 0.0000],
#         [0.7670, 0.0000],
#         [0.7780, 0.0000],
#         [1.0660, 0.0000],
#         [1.0610, 0.0000]])
# [2.5471941e-01 3.7708202e-01 6.7958218e+03]
# 12
# tensor([[0.5840, 0.0000],
#         [0.5950, 1.0000],
#         [0.5750, 0.0000],
#         [0.8600, 0.0000],
#         [0.5710, 0.0000]])
# [3.2884482e-01 4.2685747e-01 6.6874785e+03]
# 13
# tensor([[0.5740, 0.0000],
#         [0.6150, 0.0000],
#         [0.6100, 0.0000],
#         [0.5570, 0.0000],
#         [0.5600, 0.0000]])
# [3.2902876e-01 4.1371053e-01 6.6836899e+03]
# 14
# tensor([[0.6270, 0.0000],
#         [0.5590, 0.0000],
#         [0.5700, 1.0000],
#         [0.5630, 1.0000],
#         [0.5270, 1.0000]])
# [4.0651277e-02 4.5562041e-01 7.1447197e+03]
# 15
# tensor([[0.5830, 0.0000],
#         [0.6970, 1.0000],
#         [0.6140, 0.0000],
#         [0.6070, 1.0000],
#         [0.5740, 0.0000]])
# [1.5563962e-01 3.9980626e-01 6.9279785e+03]
# 16
# tensor([[0.5880, 1.0000],
#         [0.6120, 0.0000],
#         [0.5380, 1.0000],
#         [0.5710, 0.0000],
#         [0.6430, 0.0000]])
# [3.0507207e-01 3.9272881e-01 6.7101436e+03]
# 17
# tensor([[0.5470, 0.0000],
#         [0.5650, 0.0000],
#         [0.6260, 0.0000],
#         [0.6760, 0.0000],
#         [0.6790, 0.0000]])
# [3.4252295e-01 4.0310645e-01 6.6348833e+03]
# 18
# tensor([[0.6630, 0.0000],
#         [0.6170, 0.0000],
#         [0.7990, 0.0000],
#         [0.8260, 0.0000],
#         [0.5510, 0.0000]])
# [3.9133829e-01 4.3725154e-01 6.5507373e+03]
# 19
# tensor([[0.5490, 0.0000],
#         [0.5240, 0.0000],
#         [0.6500, 0.0000],
#         [0.5420, 0.0000],
#         [0.7150, 1.0000]])
# [3.5094243e-01 4.6943265e-01 6.5506460e+03]
# 20
# tensor([[0.5740, 0.0000],
#         [0.5170, 0.0000],
#         [0.5430, 0.0000],
#         [0.5730, 0.0000],
#         [0.5800, 0.0000]])
# [3.6646584e-01 5.0812370e-01 6.5282617e+03]
# 21
# tensor([[0.6490, 0.0000],
#         [0.5490, 0.0000],
#         [0.5460, 0.0000],
#         [0.7210, 0.0000],
#         [0.7650, 1.0000]])
# [3.2997715e-01 4.2436427e-01 6.6895928e+03]
# 22
# tensor([[0.7250, 0.0000],
#         [0.7790, 0.0000],
#         [0.5780, 1.0000],
#         [0.5200, 0.0000],
#         [0.5500, 0.0000]])
# [3.3828917e-01 3.9363915e-01 6.6569502e+03]
# 23
# tensor([[0.6500, 0.0000],
#         [0.6780, 0.0000],
#         [0.7400, 0.0000],
#         [0.7460, 0.0000],
#         [1.2400, 0.0000]])
# [3.4228805e-01 3.8953337e-01 6.6421338e+03]
# 24
# tensor([[0.5350, 1.0000],
#         [0.5990, 1.0000],
#         [0.6090, 1.0000],
#         [0.6270, 1.0000],
#         [0.5790, 1.0000]])
# [2.5657075e-02 4.6212554e-01 7.1766494e+03]
# 25
# tensor([[0.7900, 0.0000],
#         [0.5390, 0.0000],
#         [0.6230, 1.0000],
#         [0.5560, 0.0000],
#         [0.8210, 1.0000]])
# [2.9782254e-01 3.8493875e-01 6.7385723e+03]
# 26
# tensor([[0.5520, 0.0000],
#         [0.5970, 1.0000],
#         [0.7060, 0.0000],
#         [0.5850, 0.0000],
#         [0.6410, 0.0000]])
# [3.3139294e-01 4.1586161e-01 6.6902632e+03]
# 27
# tensor([[0.5230, 0.0000],
#         [0.5820, 0.0000],
#         [0.5680, 1.0000],
#         [0.5770, 0.0000],
#         [0.6850, 1.0000]])
# [3.8472001e-02 4.6674877e-01 7.1828516e+03]
# 28
# tensor([[0.5940, 0.0000],
#         [0.5820, 0.0000],
#         [0.5860, 0.0000],
#         [0.5610, 0.0000],
#         [0.5340, 0.0000]])
# [3.5524613e-01 4.2447615e-01 6.6381909e+03]
# 29
# tensor([[0.5870, 0.0000],
#         [0.8800, 0.0000],
#         [0.5410, 0.0000],
#         [0.6470, 0.0000],
#         [0.7140, 0.0000]])
# [3.4956574e-01 4.2913672e-01 6.6378193e+03]

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')

# %%
sim_num = 30
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, figsize=(10,10))

ax1.scatter(Is[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax2.scatter(As[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax3.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,0], s = 2)
ax4.scatter(Is[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax5.scatter(As[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax6.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,1], s = 2)
ax7.scatter(Is[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax8.scatter(As[0:sim_num], par_fitted[0:sim_num,2], s = 2)
ax9.scatter(Inhs[0:sim_num], par_fitted[0:sim_num,2], s = 2)

ax1.set_title("I")
ax2.set_title("a")
ax3.set_title("Inh")

ax1.set_ylabel("C", rotation=0)
ax4.set_ylabel("h", rotation=0)
ax7.set_ylabel("W_neg", rotation=0)
# Out:
# Text(0, 0.5, 'W_neg')
