# %%
import numpy as np
import matplotlib.pyplot as plt
# %run IDM_helper_functions.ipynb

import torch
from sbi import utils as utils
from sbi import analysis as analysis
from sbi.inference.base import infer

from sbi.inference import MNLE
from pyro.distributions import InverseGamma
from torch.distributions import Beta, Binomial, Gamma
from sbi.utils import MultipleIndependent

from sbi.inference import MCMCPosterior, VIPosterior, RejectionPosterior
from sbi.utils.torchutils import atleast_2d

from sbi.utils import mcmc_transform
from sbi.inference.potentials.base_potential import BasePotential

# %%
# Training data
num_simulations = 50000
prior = utils.BoxUniform(low=[0,0.5,0.2,0.0005, 0.1], high=[3,2,1, 0.005, 1])
parameters = prior.sample((num_simulations,))
x = simul_DDM_five_param(np.array(parameters))

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(parameters, x)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 62 epochs.

# %%
# inference with different x_o that has 10 trials
#torch.manual_seed(41)
num_trials = 50
num_samples = 100
parameters_o = prior.sample((1,))
#x_o = simul_IDM_mult_trial(np.array(parameters_o))
x_o = simul_DDM_five_param(np.array(parameters_o.repeat(num_trials, 1)))

# %%
mcmc_parameters = dict(num_chains=50,thin=10,warmup_steps=50,init_strategy="proposal")

mnle_posterior = trainer.build_posterior(mnle, prior)

mnle_samples = mnle_posterior.sample((num_samples,), x=x_o)
# Out:
# /Users/wangjiashun/Documents/GitHub/sbi/sbi/utils/sbiutils.py:321: UserWarning: An x with a batch size of 50 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   respect to entire batch, i.e,. p(theta | X)."""
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/1100 [00:00<?, ?it/s]

# %%
#pair_plot(prior, mnle_samples, parameters_o, 
contour = 0.7

fig, ax = pairplot(
    [
        prior.sample((1000,)),
        mnle_samples,
    ],
    points=parameters_o,
    diag="kde",
    upper="contour",
    kde_offdiag=dict(bins=50),
    kde_diag=dict(bins=100),
    contour_offdiag=dict(levels=[contour]),
    points_colors=["k"],
    points_offdiag=dict(marker="*", markersize=10),
    labels=['C', 'h','Ter', 'dt', 'c'],
    figsize=(5, 5)
)

#plt.sca(ax[1, 1])
plt.legend(
    ["Prior", "MNLE", 'True Parameters'],
    #frameon=False,
    fontsize=8,
    loc = 1
);

# %%
Cs = np.random.uniform(low=0, high=0.4, size=30)
hs = np.random.uniform(low=0.2, high=0.6, size=30)
Ters = np.random.uniform(low=0.1, high=0.7, size=30)

#prior = utils.BoxUniform(low=[0,0.2,0.1], high=[0.6,0.6,0.6])

# %%
n_trials = 100
num_samples = 100
par_fitted = np.zeros((30,3))

for i in range(len(Cs)):
    print(i)
    #v,a,ter = Vs[i], As[i], Ters[i]
    IDM_o = simul_IDM_mult_trial(np.tile((Cs[i], hs[i], Ters[i]), (n_trials,1))) # simulate IDM data
    
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_53410/1226283945.py in <module>
#      14     #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
#      15     mnle_posterior.set_default_x(IDM_o)
# ---> 16     mnle_map = mnle_posterior.map()
#      17
#      18     par_fitted[i,:] = np.array(mnle_map)
#
# ~/Documents/GitHub/sbi/sbi/inference/posteriors/mcmc_posterior.py in map(self, x, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars, force_update)
#     645             save_best_every=save_best_every,
#     646             show_progress_bars=show_progress_bars,
# --> 647             force_update=force_update,
#     648         )
#     649
#
# ~/Documents/GitHub/sbi/sbi/inference/posteriors/base_posterior.py in map(self, x, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars, force_update)
#     220                 num_init_samples=num_init_samples,
#     221                 save_best_every=save_best_every,
# --> 222                 show_progress_bars=show_progress_bars,
#     223             )
#     224         return self._map
#
# ~/Documents/GitHub/sbi/sbi/inference/posteriors/base_posterior.py in _calculate_map(self, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars)
#     178             learning_rate=learning_rate,
#     179             save_best_every=save_best_every,
# --> 180             show_progress_bars=show_progress_bars,
#     181         )[0]
#     182
#
# ~/Documents/GitHub/sbi/sbi/utils/sbiutils.py in gradient_ascent(potential_fn, inits, theta_transform, num_iter, num_to_optimize, learning_rate, save_best_every, show_progress_bars, interruption_note)
#     813         theta_transform = theta_transform
#     814
# --> 815     init_probs = potential_fn(inits).detach()
#     816
#     817     # Pick the `num_to_optimize` best init locations.
#
# ~/Documents/GitHub/sbi/sbi/inference/potentials/likelihood_based_potential.py in __call__(self, theta, track_gradients)
#     195             log_likelihood_trial_batch = self.likelihood_estimator.log_prob_iid(
#     196                 x=self.x_o,
# --> 197                 theta=theta.to(self.device),
#     198             )  # type: ignore
#     199             # Reshape to (x-trials x parameters), sum over trial-log likelihoods.
#
# ~/Documents/GitHub/sbi/sbi/neural_nets/mnle.py in log_prob_iid(self, x, theta)
#     380         # fill in lps for each occurred category
#     381         log_probs_discrete = log_prob_per_cat[
# --> 382             x_disc.type_as(torch.zeros(1, dtype=torch.long)).squeeze()
#     383         ].reshape(-1)
#     384
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
sim_fit_plot(Cs, hs, Ters, par_fitted, sim_num = 30)

# %%
IDM_o
# Out:
# tensor([[0.2824, 0.0000],
#         [0.2574, 1.0000],
#         [0.2494, 1.0000],
#         [0.2434, 0.0000],
#         [0.3274, 0.0000],
#         [0.2534, 0.0000],
#         [0.2644, 0.0000],
#         [0.2434, 1.0000],
#         [0.2754, 1.0000],
#         [0.2654, 1.0000],
#         [0.2924, 1.0000],
#         [0.2504, 0.0000],
#         [0.2694, 0.0000],
#         [0.2584, 1.0000],
#         [0.2594, 0.0000],
#         [0.2834, 1.0000],
#         [0.2534, 1.0000],
#         [0.2394, 0.0000],
#         [0.2534, 1.0000],
#         [0.2914, 1.0000],
#         [0.2574, 0.0000],
#         [0.2414, 1.0000],
#         [0.2704, 0.0000],
#         [0.2724, 1.0000],
#         [0.2524, 0.0000],
#         [0.2524, 0.0000],
#         [0.2674, 0.0000],
#         [0.2704, 0.0000],
#         [0.2824, 0.0000],
#         [0.2694, 0.0000],
#         [0.2534, 0.0000],
#         [0.2444, 0.0000],
#         [0.2804, 0.0000],
#         [0.2544, 0.0000],
#         [0.2524, 0.0000],
#         [0.2614, 0.0000],
#         [0.2614, 0.0000],
#         [0.2664, 0.0000],
#         [0.2254, 1.0000],
#         [0.2884, 0.0000],
#         [0.2854, 0.0000],
#         [0.2504, 0.0000],
#         [0.2614, 0.0000],
#         [0.2644, 0.0000],
#         [0.2694, 0.0000],
#         [0.2494, 1.0000],
#         [0.2794, 1.0000],
#         [0.2824, 0.0000],
#         [0.2454, 0.0000],
#         [0.2474, 0.0000],
#         [0.2474, 0.0000],
#         [0.2314, 0.0000],
#         [0.2824, 0.0000],
#         [0.2744, 0.0000],
#         [0.2664, 0.0000],
#         [0.2354, 0.0000],
#         [0.2544, 1.0000],
#         [0.2744, 0.0000],
#         [0.3114, 1.0000],
#         [0.2764, 1.0000],
#         [0.2604, 1.0000],
#         [0.2724, 0.0000],
#         [0.2604, 0.0000],
#         [0.2944, 1.0000],
#         [0.2484, 0.0000],
#         [0.2584, 1.0000],
#         [0.2584, 0.0000],
#         [0.2734, 1.0000],
#         [0.2544, 1.0000],
#         [0.2714, 0.0000],
#         [0.2734, 0.0000],
#         [0.2864, 0.0000],
#         [0.2344, 1.0000],
#         [0.2994, 1.0000],
#         [0.2514, 1.0000],
#         [0.2494, 0.0000],
#         [0.2584, 1.0000],
#         [0.2624, 0.0000],
#         [0.2284, 0.0000],
#         [0.2674, 1.0000],
#         [0.2604, 0.0000],
#         [0.2874, 0.0000],
#         [0.2764, 1.0000],
#         [0.2664, 0.0000],
#         [0.2794, 1.0000],
#         [0.2544, 1.0000],
#         [0.2854, 0.0000],
#         [0.2614, 1.0000],
#         [0.2804, 0.0000],
#         [0.2554, 0.0000],
#         [0.2434, 0.0000],
#         [0.2694, 1.0000],
#         [0.2614, 0.0000],
#         [0.2494, 0.0000],
#         [0.2514, 0.0000],
#         [0.2304, 1.0000],
#         [0.2434, 1.0000],
#         [0.2464, 0.0000],
#         [0.2834, 1.0000],
#         [0.2794, 0.0000]])
