# %%
# %run IDM_helper_functions.ipynb

# %% [markdown]
# ## Train IDM

# %%
# Training data  52500, W_neg = 8400
n_sim_train = 100000
prior = utils.BoxUniform(low=[0,0.2,0.1,0.01,51000], high=[0.2,0.6,0.6,0.1,54000])
param = prior.sample((n_sim_train,))
x_IDM_train = simul_IDM_EM5_Exc(np.array(param))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000

# %%
x_IDM_train

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(param, x_IDM_train)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 70 epochs.

# %%
mcmc_parameters = dict(num_chains=10,thin=10,warmup_steps=50,init_strategy="proposal")

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
#prior_LCA = utils.BoxUniform(low=[0,0,0.4,0.2], high=[0.4,0.5,0.8,0.5])
sim_num = 40
n_trials = 1000

prior_LCA = utils.BoxUniform(low=[0, 0.6, -0.4, 0.2], high=[1, 1.5, 0.4, 0.5])
LCA_parameters = prior_LCA.sample((sim_num,))


par_fitted = np.zeros((sim_num,5))

# %%
for i in range(sim_num):
    print(i)
    LCA_o = simul_LCA_full_simp(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
    print(LCA_parameters[i,:])
    print(LCA_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([0.7460, 1.2048, 0.2614, 0.3837])
# tensor([[3.3837, 1.0000],
#         [1.1657, 0.0000],
#         [2.5987, 0.0000],
#         [2.0517, 0.0000],
#         [0.7517, 1.0000],
#         [1.5227, 0.0000],
#         [3.1047, 0.0000],
#         [1.7237, 0.0000],
#         [0.7047, 1.0000],
#         [1.0247, 0.0000]])
# [1.8561099e-01 3.0653149e-01 1.6883875e-01 1.0942423e-02 5.1013676e+04]
# 1
# sim0
# tensor([0.3142, 1.2167, 0.1536, 0.4922])
# tensor([[2.0822, 0.0000],
#         [1.1852, 0.0000],
#         [3.0242, 0.0000],
#         [1.1952, 0.0000],
#         [1.8152, 0.0000],
#         [2.2512, 0.0000],
#         [1.3312, 0.0000],
#         [1.0532, 0.0000],
#         [2.0122, 0.0000],
#         [3.4922, 0.0000]])
# [1.9016296e-01 2.1942472e-01 2.1324889e-01 1.2064962e-02 5.1002652e+04]
# 2
# sim0
# tensor([0.5286, 1.2231, 0.1355, 0.3582])
# tensor([[1.5262, 0.0000],
#         [1.8682, 1.0000],
#         [2.0162, 0.0000],
#         [1.7142, 0.0000],
#         [2.0322, 1.0000],
#         [0.7762, 0.0000],
#         [1.8372, 0.0000],
#         [1.8522, 0.0000],
#         [1.6652, 0.0000],
#         [1.5462, 0.0000]])
# [1.8114920e-01 3.1984821e-01 1.5705130e-01 1.0141358e-02 5.1000273e+04]
# 3
# sim0
# tensor([0.7577, 1.1324, 0.0706, 0.4066])
# tensor([[0.9686, 0.0000],
#         [0.7676, 1.0000],
#         [1.2356, 0.0000],
#         [0.8966, 0.0000],
#         [1.8116, 0.0000],
#         [1.6276, 1.0000],
#         [0.5906, 0.0000],
#         [0.7076, 0.0000],
#         [1.2706, 0.0000],
#         [2.2226, 0.0000]])
# [1.8523496e-01 3.0560154e-01 1.6939360e-01 1.1640757e-02 5.1011293e+04]
# 4
# sim0
# tensor([ 0.7142,  0.6637, -0.2539,  0.2510])
# tensor([[0.6860, 0.0000],
#         [1.9400, 0.0000],
#         [0.5830, 0.0000],
#         [0.3920, 1.0000],
#         [0.6530, 0.0000],
#         [0.9350, 0.0000],
#         [0.3690, 1.0000],
#         [0.4250, 0.0000],
#         [1.0090, 0.0000],
#         [1.1940, 0.0000]])
# [1.4724821e-01 5.6415778e-01 2.3144066e-01 1.5317887e-02 5.1017047e+04]
# 5
# sim0
# tensor([ 0.3409,  1.0924, -0.1613,  0.4082])
# tensor([[1.4292, 0.0000],
#         [0.8812, 0.0000],
#         [1.2412, 0.0000],
#         [1.6602, 0.0000],
#         [3.4082, 1.0000],
#         [0.8942, 0.0000],
#         [0.7912, 0.0000],
#         [0.7162, 1.0000],
#         [0.6142, 0.0000],
#         [0.7562, 0.0000]])
# [7.9614058e-02 4.8086667e-01 3.4692448e-01 1.0132371e-02 5.1000754e+04]
# 6
# sim0
# tensor([0.4754, 1.2593, 0.0726, 0.2347])
# tensor([[1.0977, 0.0000],
#         [1.8907, 0.0000],
#         [0.8027, 1.0000],
#         [0.7387, 0.0000],
#         [0.7957, 1.0000],
#         [1.9937, 0.0000],
#         [1.7817, 0.0000],
#         [0.6627, 0.0000],
#         [3.2347, 1.0000],
#         [0.9747, 1.0000]])
# [1.14863254e-01 4.17503506e-01 1.92157388e-01 1.00608040e-02
#  5.10027539e+04]
# 7
# sim0
# tensor([ 0.4071,  0.8903, -0.1954,  0.3714])
# tensor([[1.2804, 1.0000],
#         [0.7994, 0.0000],
#         [0.8264, 0.0000],
#         [1.6004, 1.0000],
#         [0.9104, 0.0000],
#         [1.4324, 1.0000],
#         [0.9544, 1.0000],
#         [0.8324, 1.0000],
#         [0.5554, 1.0000],
#         [0.6684, 0.0000]])
# [1.1965992e-01 5.0079310e-01 2.7818358e-01 1.0950005e-02 5.1001586e+04]
# 8
# sim0
# tensor([ 0.9310,  0.8598, -0.3206,  0.4501])
# tensor([[0.9191, 0.0000],
#         [1.4101, 0.0000],
#         [1.0971, 1.0000],
#         [0.6981, 0.0000],
#         [0.7871, 0.0000],
#         [1.8191, 0.0000],
#         [0.8641, 0.0000],
#         [0.8131, 0.0000],
#         [1.2571, 1.0000],
#         [0.7551, 0.0000]])
# [1.8533310e-01 4.4139281e-01 3.2614046e-01 1.3085229e-02 5.1174629e+04]
# 9
# sim0
# tensor([ 0.8039,  1.1743, -0.3829,  0.3910])
# tensor([[2.2870, 0.0000],
#         [0.5710, 0.0000],
#         [3.3910, 1.0000],
#         [1.1490, 0.0000],
#         [1.3070, 0.0000],
#         [2.1660, 1.0000],
#         [0.8390, 0.0000],
#         [0.8780, 0.0000],
#         [0.5970, 1.0000],
#         [1.6600, 0.0000]])
# Optimization was interrupted after 100 iterations.
# [1.7089717e-01 2.3968761e-01 2.0929879e-01 1.6151890e-02 5.1133777e+04]
# 10
# sim0
# tensor([0.5408, 0.7342, 0.1724, 0.2641])
# tensor([[0.8621, 0.0000],
#         [0.8731, 0.0000],
#         [1.9411, 1.0000],
#         [0.5081, 0.0000],
#         [1.1431, 0.0000],
#         [0.4891, 0.0000],
#         [1.9081, 0.0000],
#         [0.6151, 0.0000],
#         [1.0481, 1.0000],
#         [0.8491, 0.0000]])
# Optimization was interrupted after 22 iterations.
# [1.4460337e-01 3.3487996e-01 1.1536026e-01 1.4725212e-02 5.1219469e+04]
# 11
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 for i in range(sim_num):
#       2     print(i)
# ----> 3     LCA_o = simul_LCA_full_simp(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
#       4     print(LCA_parameters[i,:])
#       5     print(LCA_o[0:10,:])
#
# File ~\AppData\Local\Temp\ipykernel_31088\3135579259.py:17, in simul_LCA_full_simp(parameters, dt, c)
#      14 y = 0 # initial location
#      16 while((y<a) and (y>-a)):
# ---> 17     dW = np.random.normal()*np.sqrt(dt)
#      18     dy = (dI - bk*y)*dt + c*dW
#      20     y = y + dy
#
# KeyboardInterrupt:

# %%
par_labels = ["dI","a", "bk","ter"]
par_fitted_labels = ["C", "h", "Ter", "D","W_Exc"]
sim_fit_plot_all(LCA_parameters[:9,:], par_fitted[:9,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(12,16))
