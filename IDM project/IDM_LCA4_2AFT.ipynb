# %%
# %run IDM_helper_functions.ipynb

# %%
np.array((x)).shape
# Out:
# (100000, 2)

# %%
x
# Out:
# tensor([[0.8520, 0.0000],
#         [0.4920, 2.0000],
#         [0.4070, 2.0000],
#         ...,
#         [0.1880, 2.0000],
#         [2.0180, 2.0000],
#         [0.2870, 2.0000]])

# %%
plt.hist(np.array((x))[:,0], bins = 100)
#plt.show()
# Out:
# (array([ 827., 3528., 5196., 5467., 5512., 4862., 4478., 4059., 3806.,
#         3307., 3030., 2757., 2453., 2311., 2076., 1990., 1660., 1716.,
#         1535., 1487., 1326., 1294., 1114., 1122., 1008., 1040.,  993.,
#          849.,  852.,  814.,  721.,  718.,  735.,  625.,  647.,  626.,
#          556.,  591.,  555.,  494.,  481.,  443.,  465.,  446.,  395.,
#          391.,  370.,  374.,  349.,  335.,  353.,  327.,  310.,  297.,
#          318.,  287.,  275.,  271.,  261.,  232.,  229.,  223.,  243.,
#          222.,  221.,  217.,  194.,  214.,  187.,  198.,  181.,  190.,
#          154.,  176.,  167.,  168.,  149.,  175.,  156.,  152.,  171.,
#          148.,  149.,  130.,  128.,  128.,  126.,  123.,  115.,  117.,
#           90.,  126.,  113.,  111.,  100.,  112.,  104.,   99.,  115.,
#         8162.]),
#  array([0.018     , 0.04782   , 0.07764   , 0.10746   , 0.13728   ,
#         0.1671    , 0.19691999, 0.22674   , 0.25656   , 0.28637999,
#         0.31619999, 0.34602001, 0.37584001, 0.40566   , 0.43548   ,
#         0.46529999, 0.49511999, 0.52494001, 0.55475998, 0.58458   ,
#         0.61440003, 0.64421999, 0.67404002, 0.70385998, 0.73368001,
#         0.76349998, 0.79332   , 0.82314003, 0.85295999, 0.88278002,
#         0.91259998, 0.94242001, 0.97223997, 1.00206006, 1.03188002,
#         1.06169999, 1.09151995, 1.12134004, 1.15116   , 1.18097997,
#         1.21080005, 1.24062002, 1.27043998, 1.30025995, 1.33008003,
#         1.3599    , 1.38971996, 1.41954005, 1.44936001, 1.47917998,
#         1.50899994, 1.53882003, 1.56863999, 1.59845996, 1.62828004,
#         1.65810001, 1.68791997, 1.71774006, 1.74756002, 1.77737999,
#         1.80719995, 1.83702004, 1.86684   , 1.89665997, 1.92648005,
#         1.95630002, 1.98611999, 2.01593995, 2.04575992, 2.07557988,
#         2.10540009, 2.13522005, 2.16504002, 2.19485998, 2.22467995,
#         2.25449991, 2.28432012, 2.31414008, 2.34396005, 2.37378001,
#         2.40359998, 2.43341994, 2.46323991, 2.49306011, 2.52288008,
#         2.55270004, 2.58252001, 2.61233997, 2.64215994, 2.6719799 ,
#         2.70180011, 2.73162007, 2.76144004, 2.79126   , 2.82107997,
#         2.85089993, 2.8807199 , 2.9105401 , 2.94036007, 2.97018003,
#         3.        ]),
#  <BarContainer object of 100 artists>)

# %%
x[0][:,0].mean()
# Out:
# tensor(1.0104)

# %%
x = x[0]

# %% [markdown]
# ## LCA parameter recovery

# %%
# Training data
num_simulations = 300000
#[0,0.5] for ∆I, [0,2] for I, [0,14] for κ and β, [0,1] for Z, and [0,1]
#prior = utils.BoxUniform(low=[0.05,0.05,1,1], high=[0.3,0.25,8,8])

#prior = utils.BoxUniform(low=[0.05,1,1,0.5], high=[0.3,8,8,0.9])
prior = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])

#prior = utils.BoxU|niform(low=[0.05,0.8,1,1,0.05], high=[0.3,1.2,8,8,0.25])

#prior = utils.BoxUniform(low=[0,0,0,0,0], high=[3,3,14,14,10])

parameters = prior.sample((num_simulations,))
x = simul_LCA_full_simp(np.array(parameters))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000
# sim100000
# sim101000
# sim102000
# sim103000
# sim104000
# sim105000
# sim106000
# sim107000
# sim108000
# sim109000
# sim110000
# sim111000
# sim112000
# sim113000
# sim114000
# sim115000
# sim116000
# sim117000
# sim118000
# sim119000
# sim120000
# sim121000
# sim122000
# sim123000
# sim124000
# sim125000
# sim126000
# sim127000
# sim128000
# sim129000
# sim130000
# sim131000
# sim132000
# sim133000
# sim134000
# sim135000
# sim136000
# sim137000
# sim138000
# sim139000
# sim140000
# sim141000
# sim142000
# sim143000
# sim144000
# sim145000
# sim146000
# sim147000
# sim148000
# sim149000
# sim150000
# sim151000
# sim152000
# sim153000
# sim154000
# sim155000
# sim156000
# sim157000
# sim158000
# sim159000
# sim160000
# sim161000
# sim162000
# sim163000
# sim164000
# sim165000
# sim166000
# sim167000
# sim168000
# sim169000
# sim170000
# sim171000
# sim172000
# sim173000
# sim174000
# sim175000
# sim176000
# sim177000
# sim178000
# sim179000
# sim180000
# sim181000
# sim182000
# sim183000
# sim184000
# sim185000
# sim186000
# sim187000
# sim188000
# sim189000
# sim190000
# sim191000
# sim192000
# sim193000
# sim194000
# sim195000
# sim196000
# sim197000
# sim198000
# sim199000
# sim200000
# sim201000
# sim202000
# sim203000
# sim204000
# sim205000
# sim206000
# sim207000
# sim208000
# sim209000
# sim210000
# sim211000
# sim212000
# sim213000
# sim214000
# sim215000
# sim216000
# sim217000
# sim218000
# sim219000
# sim220000
# sim221000
# sim222000
# sim223000
# sim224000
# sim225000
# sim226000
# sim227000
# sim228000
# sim229000
# sim230000
# sim231000
# sim232000
# sim233000
# sim234000
# sim235000
# sim236000
# sim237000
# sim238000
# sim239000
# sim240000
# sim241000
# sim242000
# sim243000
# sim244000
# sim245000
# sim246000
# sim247000
# sim248000
# sim249000
# sim250000
# sim251000
# sim252000
# sim253000
# sim254000
# sim255000
# sim256000
# sim257000
# sim258000
# sim259000
# sim260000
# sim261000
# sim262000
# sim263000
# sim264000
# sim265000
# sim266000
# sim267000
# sim268000
# sim269000
# sim270000
# sim271000
# sim272000
# sim273000
# sim274000
# sim275000
# sim276000
# sim277000
# sim278000
# sim279000
# sim280000
# sim281000
# sim282000
# sim283000
# sim284000
# sim285000
# sim286000
# sim287000
# sim288000
# sim289000
# sim290000
# sim291000
# sim292000
# sim293000
# sim294000
# sim295000
# sim296000
# sim297000
# sim298000
# sim299000

# %% [markdown]
# ## Simulate from IDM and fit with ICA

# %%
prior_IDM = utils.BoxUniform(low=[0,0.2,0.1,0.01,51500, 8200], high=[0.5,0.6,0.6,0.1,53500, 8600])
n_sim = 20
parameters_IDM = prior_IDM.sample((n_sim,))
n_trials = 1000
par_fitted = np.zeros((n_sim,4))

# %%
for i in range(n_sim):
    print(i)
    IDM_o = simul_IDM_EM6(np.tile(parameters_IDM[i,:], (n_trials,1))) # simulate LCA data
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(parameters[i,:])
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\utils\sbiutils.py:316: UserWarning: An x with a batch size of 1000 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# tensor([0.9389, 0.9030, 0.3702, 0.2450])
# [0.9997198  0.6007961  0.00445659 0.37625515]
# 1
# sim0
# tensor([0.7763, 1.2171, 0.3066, 0.2865])
# [0.98731506 0.6018398  0.3558496  0.44627124]
# 2
# sim0
# tensor([0.1152, 0.7269, 0.3553, 0.3838])
# [9.9680978e-01 6.0019153e-01 4.3756349e-04 4.8704940e-01]
# 3
# sim0
# tensor([0.6454, 1.3564, 0.2000, 0.3344])
# [0.99761176 0.6003066  0.07892775 0.3450028 ]
# 4
# sim0
# tensor([0.5894, 0.6999, 0.3559, 0.2859])
# [0.99696606 0.60017973 0.39608014 0.21210037]
# 5
# sim0
# tensor([0.8176, 1.4558, 0.1602, 0.2229])
# [9.9871004e-01 6.0139930e-01 3.4888068e-04 3.9901215e-01]
# 6
# sim0
# tensor([0.6964, 0.9836, 0.1091, 0.3190])
# [0.99988616 0.6007608  0.00379598 0.49972337]
# 7
# sim0
# tensor([0.0556, 0.8302, 0.2998, 0.3330])
# [2.4571529e-01 6.0027611e-01 3.6099003e-04 4.9985647e-01]
# 8
# sim0
# tensor([0.5631, 1.2883, 0.1950, 0.3952])
# [0.11208571 0.69736314 0.08745358 0.26355445]
# 9
# sim0
# tensor([0.9634, 0.9779, 0.3873, 0.4159])
# [0.99653095 0.6017284  0.39798918 0.21326222]
# 10
# sim0
# tensor([0.8295, 1.2898, 0.1725, 0.4300])
# [0.99961984 0.6003806  0.00560654 0.42105007]
# 11
# sim0
# tensor([0.8148, 1.0120, 0.0741, 0.3640])
# [0.00493885 0.6003844  0.00114209 0.20009848]
# 12
# sim0
# tensor([0.1751, 1.2734, 0.0443, 0.4239])
# [0.85422933 0.60011196 0.00453246 0.41621292]
# 13
# sim0
# tensor([0.7843, 1.2988, 0.3782, 0.3179])
# [0.99971646 0.60078275 0.07339267 0.34072256]
# 14
# sim0
# tensor([0.2587, 1.4141, 0.1680, 0.4361])
# [0.9973718  0.6000871  0.39938757 0.215671  ]
# 15
# sim0
# tensor([0.7646, 0.7314, 0.1834, 0.2203])
# [0.9986904  0.6050014  0.14393668 0.20008755]
# 16
# sim0
# tensor([0.6434, 1.4870, 0.3540, 0.2009])
# [0.99356914 0.60134184 0.00146159 0.48437983]
# 17
# sim0
# tensor([0.2090, 1.1313, 0.2908, 0.2055])
# [1.2914659e-01 6.0005462e-01 1.0626442e-04 4.7146893e-01]
# 18
# sim0
# tensor([0.5752, 1.0061, 0.0556, 0.4801])
# [9.9947864e-01 6.8665171e-01 5.0261896e-04 4.9991584e-01]
# 19
# sim0
# tensor([0.2714, 1.1362, 0.2192, 0.4881])
# [0.20326772 0.6000511  0.0007932  0.46025383]

# %%
par_labels = ["C", "h", "Ter", "D","W_Exc", "W_Inh"]
par_fitted_labels = ["dI", "a", "bk","Ter"]
sim_fit_plot_all(parameters_IDM[:,:], par_fitted[:,:], par_labels, par_fitted_labels, s=15)
