# %%
# %run IDM_helper_functions.ipynb

# %% [markdown]
# ## Train LCA

# %%
# Training data  52500, W_neg = 8400
n_sim_train = 500000
#prior = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])
prior = utils.BoxUniform(low=[0, 0.6, -4, 0.2], high=[2, 2, 4, 0.5])

param = prior.sample((n_sim_train,))
x_IDM_train = simul_LCA_full_simp_bound(np.array(param))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000
# sim100000
# sim101000
# sim102000
# sim103000
# sim104000
# sim105000
# sim106000
# sim107000
# sim108000
# sim109000
# sim110000
# sim111000
# sim112000
# sim113000
# sim114000
# sim115000
# sim116000
# sim117000
# sim118000
# sim119000
# sim120000
# sim121000
# sim122000
# sim123000
# sim124000
# sim125000
# sim126000
# sim127000
# sim128000
# sim129000
# sim130000
# sim131000
# sim132000
# sim133000
# sim134000
# sim135000
# sim136000
# sim137000
# sim138000
# sim139000
# sim140000
# sim141000
# sim142000
# sim143000
# sim144000
# sim145000
# sim146000
# sim147000
# sim148000
# sim149000
# sim150000
# sim151000
# sim152000
# sim153000
# sim154000
# sim155000
# sim156000
# sim157000
# sim158000
# sim159000
# sim160000
# sim161000
# sim162000
# sim163000
# sim164000
# sim165000
# sim166000
# sim167000
# sim168000
# sim169000
# sim170000
# sim171000
# sim172000
# sim173000
# sim174000
# sim175000
# sim176000
# sim177000
# sim178000
# sim179000
# sim180000
# sim181000
# sim182000
# sim183000
# sim184000
# sim185000
# sim186000
# sim187000
# sim188000
# sim189000
# sim190000
# sim191000
# sim192000
# sim193000
# sim194000
# sim195000
# sim196000
# sim197000
# sim198000
# sim199000
# sim200000
# sim201000
# sim202000
# sim203000
# sim204000
# sim205000
# sim206000
# sim207000
# sim208000
# sim209000
# sim210000
# sim211000
# sim212000
# sim213000
# sim214000
# sim215000
# sim216000
# sim217000
# sim218000
# sim219000
# sim220000
# sim221000
# sim222000
# sim223000
# sim224000
# sim225000
# sim226000
# sim227000
# sim228000
# sim229000
# sim230000
# sim231000
# sim232000
# sim233000
# sim234000
# sim235000
# sim236000
# sim237000
# sim238000
# sim239000
# sim240000
# sim241000
# sim242000
# sim243000
# sim244000
# sim245000
# sim246000
# sim247000
# sim248000
# sim249000
# sim250000
# sim251000
# sim252000
# sim253000
# sim254000
# sim255000
# sim256000
# sim257000
# sim258000
# sim259000
# sim260000
# sim261000
# sim262000
# sim263000
# sim264000
# sim265000
# sim266000
# sim267000
# sim268000
# sim269000
# sim270000
# sim271000
# sim272000
# sim273000
# sim274000
# sim275000
# sim276000
# sim277000
# sim278000
# sim279000
# sim280000
# sim281000
# sim282000
# sim283000
# sim284000
# sim285000
# sim286000
# sim287000
# sim288000
# sim289000
# sim290000
# sim291000
# sim292000
# sim293000
# sim294000
# sim295000
# sim296000
# sim297000
# sim298000
# sim299000
# sim300000
# sim301000
# sim302000
# sim303000
# sim304000
# sim305000
# sim306000
# sim307000
# sim308000
# sim309000
# sim310000
# sim311000
# sim312000
# sim313000
# sim314000
# sim315000
# sim316000
# sim317000
# sim318000
# sim319000
# sim320000
# sim321000
# sim322000
# sim323000
# sim324000
# sim325000
# sim326000
# sim327000
# sim328000
# sim329000
# sim330000
# sim331000
# sim332000
# sim333000
# sim334000
# sim335000
# sim336000
# sim337000
# sim338000
# sim339000
# sim340000
# sim341000
# sim342000
# sim343000
# sim344000
# sim345000
# sim346000
# sim347000
# sim348000
# sim349000
# sim350000
# sim351000
# sim352000
# sim353000
# sim354000
# sim355000
# sim356000
# sim357000
# sim358000
# sim359000
# sim360000
# sim361000
# sim362000
# sim363000
# sim364000
# sim365000
# sim366000
# sim367000
# sim368000
# sim369000
# sim370000
# sim371000
# sim372000
# sim373000
# sim374000
# sim375000
# sim376000
# sim377000
# sim378000
# sim379000
# sim380000
# sim381000
# sim382000
# sim383000
# sim384000
# sim385000
# sim386000
# sim387000
# sim388000
# sim389000
# sim390000
# sim391000
# sim392000
# sim393000
# sim394000
# sim395000
# sim396000
# sim397000
# sim398000
# sim399000
# sim400000
# sim401000
# sim402000
# sim403000
# sim404000
# sim405000
# sim406000
# sim407000
# sim408000
# sim409000
# sim410000
# sim411000
# sim412000
# sim413000
# sim414000
# sim415000
# sim416000
# sim417000
# sim418000
# sim419000
# sim420000
# sim421000
# sim422000
# sim423000
# sim424000
# sim425000
# sim426000
# sim427000
# sim428000
# sim429000
# sim430000
# sim431000
# sim432000
# sim433000
# sim434000
# sim435000
# sim436000
# sim437000
# sim438000
# sim439000
# sim440000
# sim441000
# sim442000
# sim443000
# sim444000
# sim445000
# sim446000
# sim447000
# sim448000
# sim449000
# sim450000
# sim451000
# sim452000
# sim453000
# sim454000
# sim455000
# sim456000
# sim457000
# sim458000
# sim459000
# sim460000
# sim461000
# sim462000
# sim463000
# sim464000
# sim465000
# sim466000
# sim467000
# sim468000
# sim469000
# sim470000
# sim471000
# sim472000
# sim473000
# sim474000
# sim475000
# sim476000
# sim477000
# sim478000
# sim479000
# sim480000
# sim481000
# sim482000
# sim483000
# sim484000
# sim485000
# sim486000
# sim487000
# sim488000
# sim489000
# sim490000
# sim491000
# sim492000
# sim493000
# sim494000
# sim495000
# sim496000
# sim497000
# sim498000
# sim499000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(param, x_IDM_train)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 56 epochs.

# %%
mcmc_parameters = dict(num_chains=10,thin=10,warmup_steps=50,init_strategy="proposal")

# %% [markdown]
# ## Simulate from LCA and fit with LCA

# %%
x = simul_LCA_full_simp(np.tile([1,1.5,0.4], (100,1)))
print((100-sum(x[:,1]))/100)
print(x[0:10,:])
# Out:
# sim0
# tensor(0.9800)
# tensor([[1.5250, 0.0000],
#         [1.2400, 0.0000],
#         [2.1500, 0.0000],
#         [0.8360, 0.0000],
#         [3.3680, 0.0000],
#         [0.7630, 0.0000],
#         [1.3050, 0.0000],
#         [0.8190, 0.0000],
#         [2.1850, 0.0000],
#         [1.9070, 0.0000]])

# %%
#prior_LCA = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])

n_trials = 2000
sim_num = 60
LCA_parameters = prior.sample((sim_num,))
par_fitted = np.zeros((sim_num,4))

# %%
for i in range(14,sim_num):
    print(i)
    LCA_o = simul_LCA_full_simp_bound(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
    print(LCA_parameters[i,:])
    print(LCA_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 14
# sim0
# sim1000
# tensor([ 0.8956,  1.2650, -0.5880,  0.4972])
# tensor([[0.6932, 0.0000],
#         [1.0052, 0.0000],
#         [1.1302, 0.0000],
#         [0.5632, 0.0000],
#         [0.6112, 0.0000],
#         [0.9232, 0.0000],
#         [1.8422, 0.0000],
#         [1.3332, 0.0000],
#         [0.6162, 0.0000],
#         [0.5552, 0.0000]])
# [ 0.00461492  1.3974936  -1.7927005   0.49152774]
# 15
# sim0
# sim1000
# tensor([1.5833, 1.3177, 2.9307, 0.2782])
# tensor([[1.2052, 1.0000],
#         [1.2342, 1.0000],
#         [1.8302, 1.0000],
#         [0.5582, 1.0000],
#         [0.5352, 1.0000],
#         [0.4452, 0.0000],
#         [1.0012, 0.0000],
#         [0.5242, 1.0000],
#         [0.4912, 0.0000],
#         [2.3212, 1.0000]])
# [1.2805945 1.3479376 2.406859  0.2713014]
# 16
# sim0
# sim1000
# tensor([1.3153, 0.7035, 0.8355, 0.2087])
# tensor([[0.2597, 0.0000],
#         [0.4337, 0.0000],
#         [0.4117, 0.0000],
#         [0.3607, 1.0000],
#         [0.3237, 0.0000],
#         [0.2487, 0.0000],
#         [0.3037, 0.0000],
#         [0.2537, 1.0000],
#         [0.2657, 0.0000],
#         [0.2787, 0.0000]])
# [1.8539872  0.67002404 2.055942   0.2138105 ]
# 17
# sim0
# sim1000
# tensor([ 1.2307,  1.5481, -1.7687,  0.2814])
# tensor([[0.8894, 0.0000],
#         [0.4364, 0.0000],
#         [0.3464, 0.0000],
#         [0.8374, 0.0000],
#         [0.4414, 0.0000],
#         [0.5524, 0.0000],
#         [0.3654, 0.0000],
#         [0.4494, 0.0000],
#         [0.5034, 0.0000],
#         [0.5674, 0.0000]])
# [ 1.2605685   1.5674512  -1.794359    0.27988434]
# 18
# sim0
# sim1000
# tensor([ 0.9055,  1.9969, -0.4308,  0.4435])
# tensor([[1.0905, 0.0000],
#         [0.6175, 0.0000],
#         [0.7135, 0.0000],
#         [3.0335, 0.0000],
#         [0.6425, 0.0000],
#         [1.2865, 0.0000],
#         [1.0915, 0.0000],
#         [1.2325, 0.0000],
#         [0.8325, 0.0000],
#         [0.9655, 0.0000]])
# [ 1.063561    1.9394326  -0.36758828  0.45281386]
# 19
# sim0
# sim1000
# tensor([ 0.8185,  1.8367, -1.6125,  0.4393])
# tensor([[0.7483, 0.0000],
#         [1.3553, 0.0000],
#         [0.7213, 0.0000],
#         [0.8273, 0.0000],
#         [0.8113, 0.0000],
#         [0.8033, 0.0000],
#         [0.8563, 0.0000],
#         [0.7913, 0.0000],
#         [0.6563, 0.0000],
#         [0.5823, 0.0000]])
# [ 1.9914316   1.7367481  -0.59959316  0.44817382]
# 20
# sim0
# sim1000
# tensor([ 1.1629,  1.8556, -0.2207,  0.3144])
# tensor([[0.5124, 0.0000],
#         [1.4274, 0.0000],
#         [1.8374, 0.0000],
#         [0.7964, 0.0000],
#         [0.8184, 0.0000],
#         [0.9604, 0.0000],
#         [0.4634, 0.0000],
#         [0.7554, 0.0000],
#         [0.5484, 1.0000],
#         [0.5484, 0.0000]])
# [1.6938528  1.7012457  0.32679558 0.3248952 ]
# 21
# sim0
# sim1000
# tensor([ 0.3446,  1.8862, -3.2791,  0.3318])
# tensor([[0.4578, 0.0000],
#         [0.5698, 0.0000],
#         [0.5568, 0.0000],
#         [0.4608, 0.0000],
#         [0.5848, 0.0000],
#         [0.4768, 0.0000],
#         [0.5718, 0.0000],
#         [0.4568, 0.0000],
#         [0.5438, 0.0000],
#         [0.6578, 0.0000]])
# [ 0.80973464  1.7645031  -3.0989838   0.3369511 ]
# 22
# sim0
# sim1000
# tensor([ 0.5762,  1.8515, -3.1263,  0.4462])
# tensor([[0.6772, 0.0000],
#         [0.7572, 0.0000],
#         [0.5612, 0.0000],
#         [0.7342, 0.0000],
#         [0.9032, 0.0000],
#         [0.6362, 0.0000],
#         [0.6062, 0.0000],
#         [0.5962, 0.0000],
#         [0.5622, 0.0000],
#         [0.5612, 0.0000]])
# [ 0.42732403  1.8645272  -3.625907    0.443985  ]
# 23
# sim0
# sim1000
# tensor([ 0.9387,  0.8908, -2.5483,  0.4079])
# tensor([[0.5089, 0.0000],
#         [0.5799, 0.0000],
#         [0.4509, 0.0000],
#         [0.5329, 1.0000],
#         [0.9419, 0.0000],
#         [0.4699, 0.0000],
#         [0.4969, 0.0000],
#         [0.4749, 1.0000],
#         [0.4469, 1.0000],
#         [0.5469, 0.0000]])
# [ 1.9191892   0.819676   -0.6388371   0.40878013]
# 24
# sim0
# sim1000
# tensor([0.3695, 0.9022, 3.2190, 0.3229])
# tensor([[0.4689, 1.0000],
#         [0.4469, 1.0000],
#         [0.5339, 1.0000],
#         [0.8619, 1.0000],
#         [0.6819, 1.0000],
#         [0.3999, 1.0000],
#         [0.5349, 1.0000],
#         [0.4639, 1.0000],
#         [0.4579, 0.0000],
#         [0.4279, 1.0000]])
# Optimization was interrupted after 298 iterations.
# [0.00499083 0.9042866  2.5889926  0.32601684]
# 25
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_2632/1908168124.py in <module>
#       1 for i in range(14,sim_num):
#       2     print(i)
# ----> 3     LCA_o = simul_LCA_full_simp_bound(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
#       4     print(LCA_parameters[i,:])
#       5     print(LCA_o[0:10,:])
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_2632/703925368.py in simul_LCA_full_simp_bound(parameters, dt, c)
#      14
#      15         while((y<a) and (y>0)):
# ---> 16             dW = np.random.normal()*np.sqrt(dt)
#      17             dy = (dI - bk*y)*dt + c*dW
#      18             y = y + dy
#
# KeyboardInterrupt:

# %%
#sim = 2000
par_labels = ["dI","a", "bk","ter"]
par_fitted_labels = ["dI","a", "bk","ter"]
sim_fit_plot_all(LCA_parameters[:24,:], par_fitted[:24,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(8,8))

# %%
n_trials = 1000
sim_num = 30

prior_IDM = utils.BoxUniform(low=[0,0.2,0.1,0.01,52000, 8200], high=[0.8,0.6,0.6,0.1,53000, 8600])
param_IDM = prior_IDM.sample((n_trials,))

par_fitted_LCA = np.zeros((sim_num,4))

# %%
for i in range(18,sim_num):
    print(i)
    IDM_o = simul_IDM_EM6(np.tile(param_IDM[i,:], (n_trials,1))) # simulate IDM data
    print(param_IDM[i,:])
    print(IDM_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted_LCA[i,:] = np.array(mnle_map)
# Out:
# 18
# sim0
# sim1000
# tensor([1.8882e-01, 4.2074e-01, 1.0730e-01, 6.0180e-02, 5.2812e+04, 8.3848e+03])
# tensor([[0.2513, 0.0000],
#         [0.2033, 1.0000],
#         [0.1733, 1.0000],
#         [0.2963, 0.0000],
#         [0.2923, 0.0000],
#         [0.2743, 0.0000],
#         [0.1943, 0.0000],
#         [0.3753, 1.0000],
#         [0.1863, 0.0000],
#         [0.2643, 0.0000]])
# Optimization was interrupted after 533 iterations.
# [1.4163402  0.61647356 1.7923622  0.20023423]
# 19
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_2632/1186880417.py in <module>
#       1 for i in range(18,sim_num):
#       2     print(i)
# ----> 3     IDM_o = simul_IDM_EM6(np.tile(param_IDM[i,:], (n_trials,1))) # simulate IDM data
#       4     print(param_IDM[i,:])
#       5     print(IDM_o[0:10,:])
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_2632/1919691436.py in simul_IDM_EM6(parameters, N, Bns, Bs, beta, theta, dt, init_loc)
#      21             dW1 = np.random.normal()*np.sqrt(dt)
#      22             dW2 = np.random.normal()*np.sqrt(dt)
# ---> 23             dy1 = -beta*D*dFdy1(y1,y2, W_pos, W_neg, B1, theta, beta, N)*dt + np.sqrt(2*D)*dW1
#      24             dy2 = -beta*D*dFdy2(y1,y2, W_pos, W_neg, B2, theta, beta, N)*dt + np.sqrt(2*D)*dW2
#      25             y1 = clamp(y1 + dy1) # clamp to [0,1]
#
# KeyboardInterrupt:

# %%
#sim = 2000
par_labels = ["C", "h", "Ter", "D","W_Exc", "W_Inh"]
par_fitted_labels = ["dI","a", "bk","ter"]
sim_fit_plot_all(param_IDM[:18,:], par_fitted_LCA[:18,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(12,8))

# %%
LCA_o_correct = LCA_o[LCA_o[:,1]==0]
LCA_o_error = LCA_o[LCA_o[:,1]==1]
print(LCA_parameters[i,:])
print(LCA_o_correct[:,0].shape)

# %%
plt.hist(LCA_o_correct[:,0], bins = 50)
plt.show()

# %%
plt.hist(LCA_o_error[:,0], bins = 50)
plt.show()

# %%
# Out:
# tensor([0.2919, 0.9177, 7.9962, 7.1314, 0.4427, 0.2263])

# %%
# Out:
# torch.Size([511])
