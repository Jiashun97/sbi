# %%
# %run IDM_helper_functions.ipynb

# %% [markdown]
# ## Train LCA

# %%
# Training data  52500, W_neg = 8400
n_sim_train = 500000
#prior = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])
prior = utils.BoxUniform(low=[0, 0.6, -8, 0.1], high=[4, 2, 8, 0.6])

param = prior.sample((n_sim_train,))
x_IDM_train = simul_LCA_full_simp_bound(np.array(param))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000
# sim100000
# sim101000
# sim102000
# sim103000
# sim104000
# sim105000
# sim106000
# sim107000
# sim108000
# sim109000
# sim110000
# sim111000
# sim112000
# sim113000
# sim114000
# sim115000
# sim116000
# sim117000
# sim118000
# sim119000
# sim120000
# sim121000
# sim122000
# sim123000
# sim124000
# sim125000
# sim126000
# sim127000
# sim128000
# sim129000
# sim130000
# sim131000
# sim132000
# sim133000
# sim134000
# sim135000
# sim136000
# sim137000
# sim138000
# sim139000
# sim140000
# sim141000
# sim142000
# sim143000
# sim144000
# sim145000
# sim146000
# sim147000
# sim148000
# sim149000
# sim150000
# sim151000
# sim152000
# sim153000
# sim154000
# sim155000
# sim156000
# sim157000
# sim158000
# sim159000
# sim160000
# sim161000
# sim162000
# sim163000
# sim164000
# sim165000
# sim166000
# sim167000
# sim168000
# sim169000
# sim170000
# sim171000
# sim172000
# sim173000
# sim174000
# sim175000
# sim176000
# sim177000
# sim178000
# sim179000
# sim180000
# sim181000
# sim182000
# sim183000
# sim184000
# sim185000
# sim186000
# sim187000
# sim188000
# sim189000
# sim190000
# sim191000
# sim192000
# sim193000
# sim194000
# sim195000
# sim196000
# sim197000
# sim198000
# sim199000
# sim200000
# sim201000
# sim202000
# sim203000
# sim204000
# sim205000
# sim206000
# sim207000
# sim208000
# sim209000
# sim210000
# sim211000
# sim212000
# sim213000
# sim214000
# sim215000
# sim216000
# sim217000
# sim218000
# sim219000
# sim220000
# sim221000
# sim222000
# sim223000
# sim224000
# sim225000
# sim226000
# sim227000
# sim228000
# sim229000
# sim230000
# sim231000
# sim232000
# sim233000
# sim234000
# sim235000
# sim236000
# sim237000
# sim238000
# sim239000
# sim240000
# sim241000
# sim242000
# sim243000
# sim244000
# sim245000
# sim246000
# sim247000
# sim248000
# sim249000
# sim250000
# sim251000
# sim252000
# sim253000
# sim254000
# sim255000
# sim256000
# sim257000
# sim258000
# sim259000
# sim260000
# sim261000
# sim262000
# sim263000
# sim264000
# sim265000
# sim266000
# sim267000
# sim268000
# sim269000
# sim270000
# sim271000
# sim272000
# sim273000
# sim274000
# sim275000
# sim276000
# sim277000
# sim278000
# sim279000
# sim280000
# sim281000
# sim282000
# sim283000
# sim284000
# sim285000
# sim286000
# sim287000
# sim288000
# sim289000
# sim290000
# sim291000
# sim292000
# sim293000
# sim294000
# sim295000
# sim296000
# sim297000
# sim298000
# sim299000
# sim300000
# sim301000
# sim302000
# sim303000
# sim304000
# sim305000
# sim306000
# sim307000
# sim308000
# sim309000
# sim310000
# sim311000
# sim312000
# sim313000
# sim314000
# sim315000
# sim316000
# sim317000
# sim318000
# sim319000
# sim320000
# sim321000
# sim322000
# sim323000
# sim324000
# sim325000
# sim326000
# sim327000
# sim328000
# sim329000
# sim330000
# sim331000
# sim332000
# sim333000
# sim334000
# sim335000
# sim336000
# sim337000
# sim338000
# sim339000
# sim340000
# sim341000
# sim342000
# sim343000
# sim344000
# sim345000
# sim346000
# sim347000
# sim348000
# sim349000
# sim350000
# sim351000
# sim352000
# sim353000
# sim354000
# sim355000
# sim356000
# sim357000
# sim358000
# sim359000
# sim360000
# sim361000
# sim362000
# sim363000
# sim364000
# sim365000
# sim366000
# sim367000
# sim368000
# sim369000
# sim370000
# sim371000
# sim372000
# sim373000
# sim374000
# sim375000
# sim376000
# sim377000
# sim378000
# sim379000
# sim380000
# sim381000
# sim382000
# sim383000
# sim384000
# sim385000
# sim386000
# sim387000
# sim388000
# sim389000
# sim390000
# sim391000
# sim392000
# sim393000
# sim394000
# sim395000
# sim396000
# sim397000
# sim398000
# sim399000
# sim400000
# sim401000
# sim402000
# sim403000
# sim404000
# sim405000
# sim406000
# sim407000
# sim408000
# sim409000
# sim410000
# sim411000
# sim412000
# sim413000
# sim414000
# sim415000
# sim416000
# sim417000
# sim418000
# sim419000
# sim420000
# sim421000
# sim422000
# sim423000
# sim424000
# sim425000
# sim426000
# sim427000
# sim428000
# sim429000
# sim430000
# sim431000
# sim432000
# sim433000
# sim434000
# sim435000
# sim436000
# sim437000
# sim438000
# sim439000
# sim440000
# sim441000
# sim442000
# sim443000
# sim444000
# sim445000
# sim446000
# sim447000
# sim448000
# sim449000
# sim450000
# sim451000
# sim452000
# sim453000
# sim454000
# sim455000
# sim456000
# sim457000
# sim458000
# sim459000
# sim460000
# sim461000
# sim462000
# sim463000
# sim464000
# sim465000
# sim466000
# sim467000
# sim468000
# sim469000
# sim470000
# sim471000
# sim472000
# sim473000
# sim474000
# sim475000
# sim476000
# sim477000
# sim478000
# sim479000
# sim480000
# sim481000
# sim482000
# sim483000
# sim484000
# sim485000
# sim486000
# sim487000
# sim488000
# sim489000
# sim490000
# sim491000
# sim492000
# sim493000
# sim494000
# sim495000
# sim496000
# sim497000
# sim498000
# sim499000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(param, x_IDM_train)
mnle = trainer.train()
# Out:
#  Neural network successfully converged after 75 epochs.

# %%
mcmc_parameters = dict(num_chains=10,thin=10,warmup_steps=50,init_strategy="proposal")

# %% [markdown]
# ## Simulate from IDM and fit with LCA

# %%
n_trials = 1000
sim_num = 30

prior_IDM = utils.BoxUniform(low=[0,0.2,0.2,52000, 8200], high=[0.8,0.6,0.5,53000, 8600])
param_IDM = prior_IDM.sample((n_trials,))

par_fitted = np.zeros((sim_num,4))

# %%
#prior_LCA = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])

# %%
for i in range(6,sim_num):
    print(i)
    IDM_o = simul_IDM_EM6(np.tile(param_IDM[i,:], (n_trials,1))) # simulate IDM data
    print(param_IDM[i,:])
    print(IDM_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(IDM_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 6
# sim0
# tensor([5.5772e-01, 4.4214e-01, 4.1207e-01, 5.2419e+04, 8.5756e+03])
# tensor([[0.4731, 0.0000],
#         [0.4611, 0.0000],
#         [0.5031, 0.0000],
#         [0.4861, 0.0000],
#         [0.4891, 0.0000],
#         [0.5481, 0.0000],
#         [0.5041, 0.0000],
#         [0.5221, 0.0000],
#         [0.6141, 0.0000],
#         [0.5701, 0.0000]])
# [ 0.0223856   1.3910301  -7.2098575   0.41769108]
# 7
# sim0
# tensor([7.4264e-01, 3.4391e-01, 2.8667e-01, 5.2839e+04, 8.4412e+03])
# tensor([[0.3387, 0.0000],
#         [0.3627, 0.0000],
#         [0.3617, 0.0000],
#         [0.3927, 0.0000],
#         [0.4007, 0.0000],
#         [0.3727, 0.0000],
#         [0.3547, 0.0000],
#         [0.3477, 0.0000],
#         [0.3857, 0.0000],
#         [0.4377, 0.0000]])
# [ 2.4344623   1.0610425  -7.9628334   0.31253982]
# 8
# sim0
# tensor([3.9963e-01, 4.0056e-01, 3.3697e-01, 5.2096e+04, 8.3168e+03])
# tensor([[0.4980, 0.0000],
#         [0.4330, 0.0000],
#         [0.4680, 0.0000],
#         [0.5910, 0.0000],
#         [0.4950, 0.0000],
#         [0.5180, 0.0000],
#         [0.4570, 0.0000],
#         [0.4590, 0.0000],
#         [0.5580, 0.0000],
#         [0.5710, 0.0000]])
# [ 0.04790243  1.3078871  -5.0201035   0.3509867 ]
# 9
# sim0
# tensor([3.0577e-01, 4.2028e-01, 2.0493e-01, 5.2165e+04, 8.2786e+03])
# tensor([[0.3379, 0.0000],
#         [0.4639, 0.0000],
#         [0.3259, 0.0000],
#         [0.3909, 0.0000],
#         [0.3789, 0.0000],
#         [0.3769, 0.0000],
#         [0.5629, 0.0000],
#         [0.7049, 1.0000],
#         [0.4189, 0.0000],
#         [0.5079, 0.0000]])
# [ 0.27804118  1.0655752  -4.747166    0.23291957]
# 10
# sim0
# tensor([3.7622e-01, 5.5385e-01, 3.8520e-01, 5.2911e+04, 8.4087e+03])
# tensor([[0.4292, 0.0000],
#         [0.4532, 0.0000],
#         [0.4622, 0.0000],
#         [0.4342, 0.0000],
#         [0.4632, 0.0000],
#         [0.4432, 0.0000],
#         [0.4342, 0.0000],
#         [0.5232, 0.0000],
#         [0.4982, 0.0000],
#         [0.4232, 0.0000]])
# [ 1.5696988  0.605874  -6.3418183  0.3947008]
# 11
# sim0
# tensor([3.0805e-01, 3.1537e-01, 4.1923e-01, 5.2298e+04, 8.4936e+03])
# tensor([[0.5422, 0.0000],
#         [0.6112, 0.0000],
#         [0.5882, 0.0000],
#         [0.5482, 0.0000],
#         [0.4922, 0.0000],
#         [0.5402, 0.0000],
#         [0.6052, 1.0000],
#         [0.7442, 0.0000],
#         [0.7612, 0.0000],
#         [0.5022, 0.0000]])
# [ 0.00613209  1.1208551  -4.4600325   0.45662755]
# 12
# sim0
# tensor([6.4428e-01, 5.9309e-01, 3.2779e-01, 5.2539e+04, 8.2831e+03])
# tensor([[0.3548, 0.0000],
#         [0.3518, 0.0000],
#         [0.3528, 0.0000],
#         [0.4058, 0.0000],
#         [0.4108, 0.0000],
#         [0.3938, 0.0000],
#         [0.3998, 0.0000],
#         [0.4018, 0.0000],
#         [0.3978, 0.0000],
#         [0.3508, 0.0000]])
# [ 3.2858922  0.6021479 -7.906384   0.3321247]
# 13
# sim0
# tensor([7.3263e-01, 4.3820e-01, 3.9953e-01, 5.2856e+04, 8.2022e+03])
# tensor([[0.5215, 0.0000],
#         [0.4335, 0.0000],
#         [0.5015, 0.0000],
#         [0.5475, 0.0000],
#         [0.4725, 1.0000],
#         [0.4595, 0.0000],
#         [0.5275, 0.0000],
#         [0.4595, 0.0000],
#         [0.4755, 0.0000],
#         [0.4795, 0.0000]])
# [ 3.2012022   0.8638511  -7.9583035   0.41841853]
# 14
# sim0
# tensor([7.6656e-01, 4.2305e-01, 2.3015e-01, 5.2266e+04, 8.5797e+03])
# tensor([[0.2871, 0.0000],
#         [0.3701, 0.0000],
#         [0.3831, 0.0000],
#         [0.2881, 0.0000],
#         [0.3741, 0.0000],
#         [0.2941, 0.0000],
#         [0.3241, 0.0000],
#         [0.3221, 0.0000],
#         [0.3361, 0.0000],
#         [0.3301, 0.0000]])
# [ 0.03436952  1.7246834  -7.580275    0.2301749 ]
# 15
# sim0
# tensor([6.1333e-01, 2.0383e-01, 4.4409e-01, 5.2696e+04, 8.2814e+03])
# tensor([[0.6191, 0.0000],
#         [0.6321, 0.0000],
#         [0.6241, 0.0000],
#         [0.5601, 0.0000],
#         [0.5541, 0.0000],
#         [0.5881, 0.0000],
#         [0.5711, 0.0000],
#         [0.6201, 0.0000],
#         [0.5931, 0.0000],
#         [0.5571, 0.0000]])
# [ 1.2314832   1.0907476  -7.994536    0.48823678]
# 16
# sim0
# tensor([3.5422e-01, 2.5957e-01, 4.7839e-01, 5.2236e+04, 8.2725e+03])
# tensor([[1.0504, 0.0000],
#         [0.8244, 0.0000],
#         [0.6884, 0.0000],
#         [0.5964, 0.0000],
#         [0.6464, 1.0000],
#         [0.6464, 0.0000],
#         [0.6484, 0.0000],
#         [0.6404, 0.0000],
#         [0.6004, 0.0000],
#         [0.6464, 0.0000]])
# [ 0.01702375  1.1936419  -4.7888017   0.5232397 ]
# 17
# sim0
# tensor([4.7033e-02, 4.3590e-01, 2.7595e-01, 5.2740e+04, 8.5627e+03])
# tensor([[0.4880, 0.0000],
#         [0.3200, 1.0000],
#         [0.4930, 1.0000],
#         [0.3840, 1.0000],
#         [0.3810, 0.0000],
#         [0.4660, 1.0000],
#         [0.3560, 0.0000],
#         [0.3660, 0.0000],
#         [0.3620, 1.0000],
#         [0.4590, 1.0000]])
# [ 0.00271027  0.68294287 -0.7617836   0.3113685 ]
# 18
# sim0
# tensor([4.8738e-01, 4.0510e-01, 2.9193e-01, 5.2362e+04, 8.5840e+03])
# tensor([[0.3789, 0.0000],
#         [0.3849, 0.0000],
#         [0.4099, 0.0000],
#         [0.5699, 0.0000],
#         [0.5129, 0.0000],
#         [0.3749, 0.0000],
#         [0.4079, 0.0000],
#         [0.4319, 0.0000],
#         [0.4019, 0.0000],
#         [0.4199, 0.0000]])
# [ 0.09907997  1.1686251  -6.851708    0.31429777]
# 19
# sim0
# tensor([4.5132e-01, 2.2324e-01, 2.9778e-01, 5.2093e+04, 8.5493e+03])
# tensor([[0.4818, 0.0000],
#         [0.6258, 0.0000],
#         [0.4898, 0.0000],
#         [0.4438, 0.0000],
#         [0.4988, 0.0000],
#         [0.4868, 0.0000],
#         [0.5888, 0.0000],
#         [0.5808, 0.0000],
#         [0.5628, 0.0000],
#         [0.4578, 0.0000]])
# [ 0.01353563  1.6466863  -4.58365     0.33667642]
# 20
# sim0
# tensor([1.6569e-01, 4.6586e-01, 3.8780e-01, 5.2227e+04, 8.5390e+03])
# tensor([[0.5828, 0.0000],
#         [0.5518, 0.0000],
#         [0.5588, 0.0000],
#         [0.6378, 0.0000],
#         [0.4558, 0.0000],
#         [0.7018, 0.0000],
#         [0.7808, 0.0000],
#         [0.5118, 0.0000],
#         [0.5448, 1.0000],
#         [0.6248, 0.0000]])
# [ 0.0026476   0.98727155 -2.5128741   0.40813088]
# 21
# sim0
# tensor([3.7280e-01, 2.9747e-01, 2.1624e-01, 5.2030e+04, 8.5922e+03])
# tensor([[0.3192, 0.0000],
#         [0.9362, 0.0000],
#         [0.3822, 0.0000],
#         [0.4962, 0.0000],
#         [0.4202, 0.0000],
#         [0.3092, 0.0000],
#         [0.3712, 0.0000],
#         [0.5172, 0.0000],
#         [0.5992, 0.0000],
#         [0.4872, 0.0000]])
# [ 0.0730378   1.4092665  -3.922151    0.24697721]
# 22
# sim0
# tensor([4.2446e-01, 4.8405e-01, 2.1856e-01, 5.2189e+04, 8.2215e+03])
# tensor([[0.3336, 0.0000],
#         [0.4066, 0.0000],
#         [0.2796, 0.0000],
#         [0.5056, 0.0000],
#         [0.2946, 0.0000],
#         [0.4216, 0.0000],
#         [0.3226, 0.0000],
#         [0.3086, 0.0000],
#         [0.3076, 0.0000],
#         [0.3356, 0.0000]])
# [ 0.18035689  1.1519976  -5.880654    0.22879684]
# 23
# sim0
# tensor([1.8386e-01, 2.7593e-01, 4.1186e-01, 5.2681e+04, 8.5480e+03])
# tensor([[0.5419, 0.0000],
#         [0.6419, 0.0000],
#         [0.6399, 0.0000],
#         [0.8829, 0.0000],
#         [0.6989, 1.0000],
#         [0.5419, 0.0000],
#         [0.4949, 0.0000],
#         [0.5919, 1.0000],
#         [0.5659, 0.0000],
#         [0.5209, 0.0000]])
# [ 1.2987249e-03  8.0199051e-01 -4.2658300e+00  4.6462888e-01]
# 24
# sim0
# tensor([4.3192e-01, 3.3575e-01, 2.8571e-01, 5.2815e+04, 8.3908e+03])
# tensor([[0.3817, 0.0000],
#         [0.3707, 0.0000],
#         [0.4137, 0.0000],
#         [0.4707, 0.0000],
#         [0.3537, 0.0000],
#         [0.3817, 0.0000],
#         [0.4307, 0.0000],
#         [0.3857, 1.0000],
#         [0.4737, 0.0000],
#         [0.3597, 0.0000]])
# [ 0.5190625   0.82823116 -7.9847193   0.32551628]
# 25
# sim0
# tensor([7.2604e-01, 4.3395e-01, 3.2844e-01, 5.2548e+04, 8.4606e+03])
# tensor([[0.4284, 0.0000],
#         [0.4144, 0.0000],
#         [0.4354, 0.0000],
#         [0.4374, 0.0000],
#         [0.3914, 0.0000],
#         [0.3614, 0.0000],
#         [0.3944, 0.0000],
#         [0.3704, 0.0000],
#         [0.4394, 0.0000],
#         [0.4124, 0.0000]])
# [ 1.6883036  1.1327782 -7.9814143  0.3431339]
# 26
# sim0
# tensor([3.8425e-01, 5.9915e-01, 3.6677e-01, 5.2448e+04, 8.4840e+03])
# tensor([[0.4028, 0.0000],
#         [0.4128, 0.0000],
#         [0.4128, 0.0000],
#         [0.3938, 0.0000],
#         [0.3998, 0.0000],
#         [0.4438, 0.0000],
#         [0.4338, 0.0000],
#         [0.4798, 0.0000],
#         [0.4138, 0.0000],
#         [0.3928, 0.0000]])
# Optimization was interrupted after 707 iterations.
# [ 1.2411348   0.62261975 -7.100335    0.36738747]
# 27
# sim0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_34624/199736485.py in <module>
#       1 for i in range(6,sim_num):
#       2     print(i)
# ----> 3     IDM_o = simul_IDM_EM6(np.tile(param_IDM[i,:], (n_trials,1))) # simulate IDM data
#       4     print(param_IDM[i,:])
#       5     print(IDM_o[0:10,:])
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_34624/2948105927.py in simul_IDM_EM6(parameters, N, Bns, Bs, beta, theta, dt, init_loc)
#      19         loc_y1, loc_y2 = [], []
#      20
# ---> 21         while get_state(y1=y1, y2=y2, h=h)==0:
#      22             dW1 = np.random.normal()*np.sqrt(dt)
#      23             dW2 = np.random.normal()*np.sqrt(dt)
#
# /var/folders/5g/vqmn12yd48z6l6jf2s2yy62r0000gn/T/ipykernel_34624/2375999865.py in get_state(y1, y2, h)
#      43     if(y1>(1-h))&(y2<h):
#      44         state = 1
# ---> 45     elif(y1<h)&(y2>(1-h)):
#      46         state = 2
#      47     else:
#
# KeyboardInterrupt:

# %%
par_labels = ["C", "h", "Ter","W_Exc", "W_Inh"]
par_fitted_labels = ["dI","a", "bk","ter"]
sim_fit_plot_all(param_IDM[:26,:], par_fitted[:26,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(10,8))

# %%
LCA_o_correct = LCA_o[LCA_o[:,1]==0]
LCA_o_error = LCA_o[LCA_o[:,1]==1]
print(LCA_parameters[i,:])
print(LCA_o_correct[:,0].shape)

# %%
plt.hist(LCA_o_correct[:,0], bins = 50)
plt.show()

# %%
plt.hist(LCA_o_error[:,0], bins = 50)
plt.show()

# %%
# Out:
# tensor([0.2919, 0.9177, 7.9962, 7.1314, 0.4427, 0.2263])

# %%
# Out:
# torch.Size([511])
