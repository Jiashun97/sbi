# %%
# %run IDM_helper_functions.ipynb

# %% [markdown]
# ## Train IDM

# %%
# Training data  52500, W_neg = 8400
n_sim_train = 100000
prior = utils.BoxUniform(low=[0,0.2,52000, 8200], high=[0.8,0.6,53000, 8600])
param = prior.sample((n_sim_train,))
x_IDM_train = simul_IDM_EM6_WO_D_TER(np.array(param))
# Out:
# sim0
# sim1000
# sim2000
# sim3000
# sim4000
# sim5000
# sim6000
# sim7000
# sim8000
# sim9000
# sim10000
# sim11000
# sim12000
# sim13000
# sim14000
# sim15000
# sim16000
# sim17000
# sim18000
# sim19000
# sim20000
# sim21000
# sim22000
# sim23000
# sim24000
# sim25000
# sim26000
# sim27000
# sim28000
# sim29000
# sim30000
# sim31000
# sim32000
# sim33000
# sim34000
# sim35000
# sim36000
# sim37000
# sim38000
# sim39000
# sim40000
# sim41000
# sim42000
# sim43000
# sim44000
# sim45000
# sim46000
# sim47000
# sim48000
# sim49000
# sim50000
# sim51000
# sim52000
# sim53000
# sim54000
# sim55000
# sim56000
# sim57000
# sim58000
# sim59000
# sim60000
# sim61000
# sim62000
# sim63000
# sim64000
# sim65000
# sim66000
# sim67000
# sim68000
# sim69000
# sim70000
# sim71000
# sim72000
# sim73000
# sim74000
# sim75000
# sim76000
# sim77000
# sim78000
# sim79000
# sim80000
# sim81000
# sim82000
# sim83000
# sim84000
# sim85000
# sim86000
# sim87000
# sim88000
# sim89000
# sim90000
# sim91000
# sim92000
# sim93000
# sim94000
# sim95000
# sim96000
# sim97000
# sim98000
# sim99000

# %%
# Train MNLE and obtain MCMC-based posterior.

trainer = MNLE(prior=prior)
trainer = trainer.append_simulations(param, x_IDM_train)
mnle = trainer.train()
# Out:
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\neural_nets\mnle.py:60: UserWarning: The mixed neural likelihood estimator assumes that x contains
#         continuous data in the first n-1 columns (e.g., reaction times) and
#         categorical data in the last column (e.g., corresponding choices). If
#         this is not the case for the passed `x` do not use this function.
#   warnings.warn(
#  Neural network successfully converged after 69 epochs.

# %%
mcmc_parameters = dict(num_chains=10,thin=10,warmup_steps=50,init_strategy="proposal")

# %% [markdown]
# ## Simulate from LCA and fit with IDM

# %%
x = simul_LCA_full_simp(np.tile([1,1.5,0.4], (100,1)))
print((100-sum(x[:,1]))/100)
print(x[0:10,:])
# Out:
# sim0
# tensor(0.9800)
# tensor([[1.5250, 0.0000],
#         [1.2400, 0.0000],
#         [2.1500, 0.0000],
#         [0.8360, 0.0000],
#         [3.3680, 0.0000],
#         [0.7630, 0.0000],
#         [1.3050, 0.0000],
#         [0.8190, 0.0000],
#         [2.1850, 0.0000],
#         [1.9070, 0.0000]])

# %%
#prior_LCA = utils.BoxUniform(low=[0, 0.6, 0, 0.2], high=[1, 1.5, 0.4, 0.5])

prior_LCA = utils.BoxUniform(low=[0,0,0.4,0.3], high=[0.4,0.5,0.8,0.3])

LCA_parameters = prior_LCA.sample((20,))

n_trials = 300
sim_num = 20

par_fitted = np.zeros((sim_num,4))

# %%
for i in range(sim_num):
    print(i)
    LCA_o = simul_LCA_full_simp(np.tile(LCA_parameters[i,:], (n_trials,1))) # simulate IDM data
    print(LCA_parameters[i,:])
    print(LCA_o[0:10,:])
    mnle_posterior = trainer.build_posterior(
    mcmc_method="slice_np_vectorized", mcmc_parameters=mcmc_parameters, prior = prior
    )
    
    #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
    mnle_posterior.set_default_x(LCA_o)
    mnle_map = mnle_posterior.map()
    print(np.array(mnle_map))
    par_fitted[i,:] = np.array(mnle_map)
# Out:
# 0
# sim0
# tensor([0.3742, 0.4544, 0.7841, 0.3000])
# tensor([[0.3440, 1.0000],
#         [0.3780, 1.0000],
#         [0.3940, 1.0000],
#         [0.4100, 0.0000],
#         [0.6580, 0.0000],
#         [0.4200, 0.0000],
#         [0.5740, 0.0000],
#         [0.6230, 1.0000],
#         [0.5570, 0.0000],
#         [0.4170, 0.0000]])
# C:\Users\ra36qix\Documents\GitHub\sbi\sbi\utils\sbiutils.py:316: UserWarning: An x with a batch size of 300 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# [1.5455753e-01 5.9984285e-01 5.2996176e+04 8.3483965e+03]
# 1
# sim0
# tensor([0.3292, 0.1472, 0.6044, 0.3000])
# tensor([[0.3390, 0.0000],
#         [0.3400, 1.0000],
#         [0.3150, 0.0000],
#         [0.3400, 0.0000],
#         [0.3260, 0.0000],
#         [0.3220, 1.0000],
#         [0.3720, 1.0000],
#         [0.3190, 1.0000],
#         [0.3680, 1.0000],
#         [0.4400, 1.0000]])
# [1.6298716e-01 5.9938711e-01 5.2998812e+04 8.3587334e+03]
# 2
# sim0
# tensor([0.2964, 0.1614, 0.5665, 0.3000])
# tensor([[0.3060, 1.0000],
#         [0.3140, 0.0000],
#         [0.3130, 1.0000],
#         [0.3500, 0.0000],
#         [0.3300, 1.0000],
#         [0.3100, 1.0000],
#         [0.3190, 1.0000],
#         [0.3280, 0.0000],
#         [0.3070, 1.0000],
#         [0.3270, 1.0000]])
# [1.6212584e-01 5.9998083e-01 5.2997820e+04 8.3558086e+03]
# 3
# sim0
# tensor([0.0080, 0.1765, 0.4716, 0.3000])
# tensor([[0.3200, 1.0000],
#         [0.3440, 1.0000],
#         [0.3350, 0.0000],
#         [0.3640, 0.0000],
#         [0.3790, 1.0000],
#         [0.3160, 0.0000],
#         [0.3950, 0.0000],
#         [0.3120, 1.0000],
#         [0.3410, 0.0000],
#         [0.3340, 0.0000]])
# [1.5974355e-01 5.9994507e-01 5.2999207e+04 8.3550645e+03]
# 4
# sim0
# tensor([0.1381, 0.3185, 0.6042, 0.3000])
# tensor([[0.3410, 1.0000],
#         [0.4330, 1.0000],
#         [0.3900, 1.0000],
#         [0.4760, 1.0000],
#         [0.3830, 1.0000],
#         [0.3610, 0.0000],
#         [0.3440, 1.0000],
#         [0.3980, 0.0000],
#         [0.4190, 1.0000],
#         [0.3470, 1.0000]])
# [1.2038636e-01 5.9992516e-01 5.2999434e+04 8.3630508e+03]
# 5
# sim0
# tensor([0.1264, 0.3988, 0.5079, 0.3000])
# tensor([[0.5520, 0.0000],
#         [0.3950, 0.0000],
#         [0.3380, 1.0000],
#         [0.4420, 0.0000],
#         [0.4050, 0.0000],
#         [0.5850, 1.0000],
#         [0.3730, 0.0000],
#         [0.6520, 0.0000],
#         [0.3650, 0.0000],
#         [0.6300, 1.0000]])
# [1.18892685e-01 5.99982798e-01 5.29962188e+04 8.36133203e+03]
# 6
# sim0
# tensor([0.2250, 0.1802, 0.7336, 0.3000])
# tensor([[0.4120, 1.0000],
#         [0.3430, 1.0000],
#         [0.3060, 0.0000],
#         [0.5030, 1.0000],
#         [0.4380, 1.0000],
#         [0.3480, 0.0000],
#         [0.3140, 1.0000],
#         [0.3270, 1.0000],
#         [0.3070, 1.0000],
#         [0.3410, 0.0000]])
# [1.5988992e-01 5.9986073e-01 5.2999504e+04 8.3554102e+03]
# 7
# sim0
# tensor([0.3527, 0.0016, 0.5661, 0.3000])
# tensor([[0.3020, 0.0000],
#         [0.3020, 1.0000],
#         [0.3020, 0.0000],
#         [0.3020, 1.0000],
#         [0.3020, 1.0000],
#         [0.3020, 0.0000],
#         [0.3020, 1.0000],
#         [0.3020, 0.0000],
#         [0.3020, 0.0000],
#         [0.3020, 1.0000]])
# [3.2819987e-03 5.9974766e-01 5.2998582e+04 8.3813125e+03]
# 8
# sim0
# tensor([0.2811, 0.2487, 0.6481, 0.3000])
# tensor([[0.3200, 0.0000],
#         [0.3470, 0.0000],
#         [0.3410, 0.0000],
#         [0.4560, 0.0000],
#         [0.3260, 1.0000],
#         [0.3920, 0.0000],
#         [0.7060, 1.0000],
#         [0.3760, 0.0000],
#         [0.3240, 1.0000],
#         [0.3420, 1.0000]])
# [1.5954182e-01 5.9983879e-01 5.2999684e+04 8.3549922e+03]
# 9
# sim0
# tensor([0.0373, 0.3007, 0.7212, 0.3000])
# tensor([[0.3890, 1.0000],
#         [0.4230, 0.0000],
#         [0.3520, 0.0000],
#         [0.6250, 0.0000],
#         [0.3410, 0.0000],
#         [0.3690, 0.0000],
#         [0.5800, 1.0000],
#         [0.3870, 1.0000],
#         [0.4550, 1.0000],
#         [0.3610, 1.0000]])
# Optimization was interrupted after 689 iterations.
# [1.610512e-01 5.995557e-01 5.299587e+04 8.356140e+03]
# 10
# sim0
# tensor([0.2194, 0.4382, 0.5953, 0.3000])
# tensor([[0.5540, 0.0000],
#         [0.3490, 0.0000],
#         [0.6160, 0.0000],
#         [0.5510, 1.0000],
#         [0.4240, 1.0000],
#         [0.8190, 1.0000],
#         [0.4560, 1.0000],
#         [0.6470, 1.0000],
#         [0.5660, 1.0000],
#         [0.7330, 1.0000]])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 #mnle_samples = mnle_posterior.sample((num_samples,), x=x_o) # fit with IDM
#      11 mnle_posterior.set_default_x(LCA_o)
# ---> 12 mnle_map = mnle_posterior.map()
#      13 print(np.array(mnle_map))
#      14 par_fitted[i,:] = np.array(mnle_map)
#
# File ~\Documents\GitHub\sbi\sbi\inference\posteriors\mcmc_posterior.py:638, in MCMCPosterior.map(self, x, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars, force_update)
#     583 def map(
#     584     self,
#     585     x: Optional[Tensor] = None,
#    (...)
#     593     force_update: bool = False,
#     594 ) -> Tensor:
#     595     r"""Returns the maximum-a-posteriori estimate (MAP).
#     596
#     597     The method can be interrupted (Ctrl-C) when the user sees that the
#    (...)
#     636         The MAP estimate.
#     637     """
# --> 638     return super().map(
#     639         x=x,
#     640         num_iter=num_iter,
#     641         num_to_optimize=num_to_optimize,
#     642         learning_rate=learning_rate,
#     643         init_method=init_method,
#     644         num_init_samples=num_init_samples,
#     645         save_best_every=save_best_every,
#     646         show_progress_bars=show_progress_bars,
#     647         force_update=force_update,
#     648     )
#
# File ~\Documents\GitHub\sbi\sbi\inference\posteriors\base_posterior.py:215, in NeuralPosterior.map(self, x, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars, force_update)
#     213 if self._map is None or force_update:
#     214     self.potential_fn.set_x(self.default_x)
# --> 215     self._map = self._calculate_map(
#     216         num_iter=num_iter,
#     217         num_to_optimize=num_to_optimize,
#     218         learning_rate=learning_rate,
#     219         init_method=init_method,
#     220         num_init_samples=num_init_samples,
#     221         save_best_every=save_best_every,
#     222         show_progress_bars=show_progress_bars,
#     223     )
#     224 return self._map
#
# File ~\Documents\GitHub\sbi\sbi\inference\posteriors\base_posterior.py:172, in NeuralPosterior._calculate_map(self, num_iter, num_to_optimize, learning_rate, init_method, num_init_samples, save_best_every, show_progress_bars)
#     169 else:
#     170     raise ValueError
# --> 172 return gradient_ascent(
#     173     potential_fn=self.potential_fn,
#     174     inits=inits,
#     175     theta_transform=self.theta_transform,
#     176     num_iter=num_iter,
#     177     num_to_optimize=num_to_optimize,
#     178     learning_rate=learning_rate,
#     179     save_best_every=save_best_every,
#     180     show_progress_bars=show_progress_bars,
#     181 )[0]
#
# File ~\Documents\GitHub\sbi\sbi\utils\sbiutils.py:816, in gradient_ascent(potential_fn, inits, theta_transform, num_iter, num_to_optimize, learning_rate, save_best_every, show_progress_bars, interruption_note)
#     813 else:
#     814     theta_transform = theta_transform
# --> 816 init_probs = potential_fn(inits).detach()
#     818 # Pick the `num_to_optimize` best init locations.
#     819 sort_indices = torch.argsort(init_probs, dim=0)
#
# File ~\Documents\GitHub\sbi\sbi\inference\potentials\likelihood_based_potential.py:196, in MixedLikelihoodBasedPotential.__call__(self, theta, track_gradients)
#     189 def __call__(self, theta: Tensor, track_gradients: bool = True) -> Tensor:
#     190
#     191     # Calculate likelihood in one batch.
#     192     with torch.set_grad_enabled(track_gradients):
#     193         # Call the specific log prob method of the mixed likelihood estimator as
#     194         # this optimizes the evaluation of the discrete data part.
#     195         # TODO: how to fix pyright issues?
# --> 196         log_likelihood_trial_batch = self.likelihood_estimator.log_prob_iid(
#     197             x=self.x_o,
#     198             theta=theta.to(self.device),
#     199         )  # type: ignore
#     200         # Reshape to (x-trials x parameters), sum over trial-log likelihoods.
#     201         log_likelihood_trial_sum = log_likelihood_trial_batch.reshape(
#     202             self.x_o.shape[0], -1
#     203         ).sum(0)
#
# File ~\Documents\GitHub\sbi\sbi\neural_nets\mnle.py:386, in MixedDensityEstimator.log_prob_iid(self, x, theta)
#     381 log_probs_discrete = log_prob_per_cat[
#     382     x_disc.type_as(torch.zeros(1, dtype=torch.long)).squeeze()
#     383 ].reshape(-1)
#     385 # Get repeat discrete data and theta to match in batch shape for flow eval.
# --> 386 log_probs_cont = self.continuous_net.log_prob(
#     387     torch.log(x_cont_repeated) if self.log_transform_x else x_cont_repeated,
#     388     context=torch.cat((theta_repeated, x_disc_repeated), dim=1),
#     389 )
#     391 # Combine into joint lp with first dim over trials.
#     392 log_probs_combined = (log_probs_discrete + log_probs_cont).reshape(
#     393     num_trials, batch_size
#     394 )
#
# File ~\.conda\envs\sbi_env\lib\site-packages\nflows\distributions\base.py:40, in Distribution.log_prob(self, inputs, context)
#      36     if inputs.shape[0] != context.shape[0]:
#      37         raise ValueError(
#      38             "Number of input items must be equal to number of context items."
#      39         )
# ---> 40 return self._log_prob(inputs, context)
#
# File ~\.conda\envs\sbi_env\lib\site-packages\nflows\flows\base.py:39, in Flow._log_prob(self, inputs, context)
#      37 def _log_prob(self, inputs, context):
#      38     embedded_context = self._embedding_net(context)
# ---> 39     noise, logabsdet = self._transform(inputs, context=embedded_context)
#      40     log_prob = self._distribution.log_prob(noise, context=embedded_context)
#      41     return log_prob + logabsdet
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\.conda\envs\sbi_env\lib\site-packages\nflows\transforms\base.py:56, in CompositeTransform.forward(self, inputs, context)
#      54 def forward(self, inputs, context=None):
#      55     funcs = self._transforms
# ---> 56     return self._cascade(inputs, funcs, context)
#
# File ~\.conda\envs\sbi_env\lib\site-packages\nflows\transforms\base.py:50, in CompositeTransform._cascade(inputs, funcs, context)
#      48 total_logabsdet = inputs.new_zeros(batch_size)
#      49 for func in funcs:
# ---> 50     outputs, logabsdet = func(outputs, context)
#      51     total_logabsdet += logabsdet
#      52 return outputs, total_logabsdet
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\.conda\envs\sbi_env\lib\site-packages\nflows\transforms\coupling.py:83, in CouplingTransform.forward(self, inputs, context)
#      80 identity_split = inputs[:, self.identity_features, ...]
#      81 transform_split = inputs[:, self.transform_features, ...]
# ---> 83 transform_params = self.transform_net(identity_split, context)
#      84 transform_split, logabsdet = self._coupling_transform_forward(
#      85     inputs=transform_split, transform_params=transform_params
#      86 )
#      88 if self.unconditional_transform is not None:
#
# File ~\Documents\GitHub\sbi\sbi\neural_nets\flow.py:363, in ContextSplineMap.__call__(self, inputs, context, *args, **kwargs)
#     351 def __call__(self, inputs: Tensor, context: Tensor, *args, **kwargs) -> Tensor:
#     352     """
#     353     Return parameters of the spline given the context.
#     354
#    (...)
#     361         Spline parameters.
#     362     """
# --> 363     return self.spline_predictor(context)
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\.conda\envs\sbi_env\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
par_labels = ["dI","a", "bk","ter"]
par_fitted_labels = ["C", "h","W_Exc", "W_Inh"]
sim_fit_plot_all(LCA_parameters[:9,:], par_fitted[:9,:], par_labels, par_fitted_labels, 
                 s = 15, figsize=(12,12))

# %%
LCA_o_correct = LCA_o[LCA_o[:,1]==0]
LCA_o_error = LCA_o[LCA_o[:,1]==1]
print(LCA_parameters[i,:])
print(LCA_o_correct[:,0].shape)

# %%
plt.hist(LCA_o_correct[:,0], bins = 50)
plt.show()

# %%
plt.hist(LCA_o_error[:,0], bins = 50)
plt.show()

# %%
# Out:
# tensor([0.2919, 0.9177, 7.9962, 7.1314, 0.4427, 0.2263])

# %%
# Out:
# torch.Size([511])
